# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.3: Web Scraping
# INSTRUCTIONS:
# - Read the guides and hints then create the necessary analysis and code to find an answer and conclusion for the task below.

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Find a Page
# Visit the [Fandom](http://fandom.wikia.com) website, find a wikia of your interest and pick a page to work with.

# %% [markdown]
# Open a web page with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the main text inside a few levels of HTML tags.

# %%
## Import Libraries
import regex as re

from urllib.parse import unquote 
import urllib3
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
OP_page = 'https://onepiece.fandom.com/wiki/One_Piece_Wiki'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
http = urllib3.PoolManager()
r = http.request('GET', OP_page)
if r.status == 200:
    page = r.data
    print('Type of variable \'page\':', page.__class__.__name__)
    print('Page Retrieved. Request Status: %d, Page Size: %d' % (r.status, len(page)))
else:
    print('Some problem occured. Request Status: %s' % r.status)
# Out:
# Type of variable 'page': bytes
# Page Retrieved. Request Status: 200, Page Size: 488756

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
# pass the page to beautifulsoup  
soup = BeautifulSoup(page, 'html.parser')
print('Type of the varible \'soup\':', soup.__class__.__name__)
# Out:
# Type of the varible 'soup': BeautifulSoup

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print(soup.prettify()[:3000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    One Piece Wiki | Fandom
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"One_Piece_Wiki","wgTitle":"One Piece Wiki","wgCurRevisionId":1838613,"wgRevisionId":1838613,"wgArticleId":291028,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using DynamicPageList parser tag","One Piece Encyclopedia"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"One_Piece_Wiki","wgRelevantArticleId":291028,"wgRequestId":"303a9dceecea9a25","wgCSPNonce":false,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":true,"wgNoExternals":false,"wgArticleInterlangList":["ar:","ca:","cs:","de:","el:","es:","eu:","fi:","fr:","he:","id:","it:","ja:","ka:","ko:","my:","nl:","no:","pl:","pt:","ro:","ru:","sv:","tr:","uk:","vi:","zh:"],"wikiaPageType":"home","isDarkTheme":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":false},"wgIsTestModeEnabled":false,"wgEnableLightboxExt":true,"wgPopupsReferencePreviews":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgEnablePopups":false,"wgIsTestWiki":false,"wgMFDisplayWikibaseDescriptions":{"search":false,"nearby":false,"watchlist":false,"tagline":false},"egMapsScriptPath":"/extensions/Maps/","egMapsDebugJS":false,"egMapsAvailableServices":["leaflet","googlemaps3"],"egMapsLeafletLayersApiKeys":{"MapBox":"","MapQuestOpen":"","Thunderforest":"","GeoportailFrance":""},"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":false,"wgCodeMirrorEnabled":true,"egFacebookAppId":"112328095453510","comscoreKeyword":"wikiacsid_anime","quantcastLabels":"TV.hulu,TV.cn,TV.fox,Theme.pirates,Genre.adventure,Genre.anime,Media.tv,Media.cards,Genre.shonen,Genre.action,Genre.fighting,Genre.manga,Genre.comedy,Genre.drama,Genre.fantasy,Genre.thriller,Genre.live-action,Genre.rpg,Genre.openworld,Media.movies,Media.books,Media.comics,Media.lightnovel,Media.games,TV.crunchyroll,TV.funimation,TV.netflix,TV.amazon,Theme.japan,Theme.

# %% [markdown]
# ### Check the HTML's Title

# %%
print('Title tag : %s:' % soup.title)
print('Title text : %s:' % soup.title.string)
# Out:
# Title tag : <title>One Piece Wiki | Fandom</title>:
# Title text : One Piece Wiki | Fandom:

# %% [markdown]
# ### Find the main content
# - Check if it is possible to use only the relevant data

# %%
article = results[0]
article.text
# Out:
# '\n\n\nWelcome to the One Piece Wiki!\n\n\nRead the first chapter or latest chapter | Watch the first episode or latest episode\n\n\n\n\n\n#portal_content-0\n#portal_content-1\n#portal_content-2\n#portal_content-3\n#portal_content-4\n#portal_content-5\n\n\n\nSail into the World of One Piece\nThe Manga\nThe Anime\nCharacters\nStampede\n\n\n\n\n\n\n\n\n\nedit\n\n\n\nCharacters\nSocieties\nLocations\nOrganizations\nDevil Fruits\nFor New Users\n\nMonkey D. Luffy\nStraw Hat Pirates\nList of Canon Characters\nList of Non-Canon Characters\nPirates\nMarines\nBy Race\nAntagonists\n\nOccupation\nBy Race\nTechnology\nAnimal Species\n\nGrand Line\nIslands\nEast Blue\nNew World\n\nMarines\nPirates\nSeven Warlords of the Sea\nFour Emperors\nWorld Government\nRevolutionary Army\n\n\nAbout Devil Fruits\nGomu Gomu no Mi\nParamecia\nZoan\nLogia\nArtificial Devil Fruits\nNatural Devil Fruits\nSMILES\nNon-Canon Devil Fruits\n\n\nGuidelines to read before editing\nReferencing Information\nCustomizing and Using Signatures\nFrequently Asked Questions\nJoin A Wiki Crew Today!\nChapter summaries that need work\nEpisode summaries that need work\nChat with fellow users on the Discord Chat!\nSomeone will invite you.\n\n\n\n\n\n\n\n\n\n\n\nedit\n\n\n\nVolumes\nSBS\nAuthor\'s Notes\nDatabooks\nCover Stories\n\nVolumes 1-10\nVolumes 11-20\nVolumes 21-30\nVolumes 31-40\nVolumes 41-50\nVolumes 51-60\nVolumes 61-70\nVolumes 71-80\nVolumes 81-90\nVolumes 91-100\nVolumes 101-110\nSpecial\n\n\nSBS Volume 4\nSBS Volume 5\nSBS Volume 6\nSBS Volume 7\nSBS Volume 8\nSBS Volume 9\nSBS Volume 10\nSBS Volume 11\nSBS Volume 12\nSBS Volume 13\nSBS Volume 14\nSBS Volume 15\nSBS Volume 16\nSBS Volume 17\nSBS Volume 18\nSBS Volume 19\nSBS Volume 20\nSBS Volume 21\nSBS Volume 22\nSBS Volume 23\nSBS Volume 24\nSBS Volume 25\nSBS Volume 26\nSBS Volume 27\nSBS Volume 28\nSBS Volume 29\nSBS Volume 30\nSBS Volume 31\nSBS Volume 32\nSBS Volume 33\nSBS Volume 34\nSBS Volume 35\nSBS Volume 36\nSBS Volume 37\nSBS Volume 38\nSBS Volume 39\nSBS Volume 40\nSBS Volume 41\nSBS Volume 42\nSBS Volume 43\nSBS Volume 44\nSBS Volume 45\nSBS Volume 46\nSBS Volume 47\nSBS Volume 48\nSBS Volume 49\nSBS Volume 50\nSBS Volume 51\nSBS Volume 52\nSBS Volume 53\nSBS Volume 54\nSBS Volume 55\nSBS Volume 56\nSBS Volume 57\nSBS Volume 58\nSBS Volume 59\nSBS Volume 60\nSBS Volume 61\nSBS Volume 62\nSBS Volume 63\nSBS Volume 64\nSBS Volume 65\nSBS Volume 66\nSBS Volume 67\nSBS Volume 68\nSBS Volume 69\nSBS Volume 70\nSBS Volume 71\nSBS Volume 72\nSBS Volume 73\nSBS Volume 74\nSBS Volume 75\nSBS Volume 76\nSBS Volume 77\nSBS Volume 78\nSBS Volume 79\nSBS Volume 80\nSBS Volume 81\nSBS Volume 82\nSBS Volume 83\nSBS Volume 84\nSBS Volume 85\nSBS Volume 86\nSBS Volume 87\nSBS Volume 88\nSBS Volume 89\nSBS Volume 90\nSBS Volume 91\nSBS Volume 92\nSBS Volume 93\nSBS Volume 94\nSBS Volume 95\nSBS Volume 96\nSBS Volume 97\nSBS Volume 98\nSBS Volume 99\nSBS Volume 100\nSBS Volume 101\n\n\n\nVolume 1\nVolume 2\nVolume 3\nVolume 4\nVolume 5\nVolume 6\nVolume 7\nVolume 8\nVolume 9\nVolume 10\nVolume 11\nVolume 12\nVolume 13\nVolume 14\nVolume 15\nVolume 16\nVolume 17\nVolume 18\nVolume 19\nVolume 20\nVolume 21\nVolume 22\nVolume 23\nVolume 24\nVolume 25\nVolume 26\nVolume 27\nVolume 28\nVolume 29\nVolume 30\nVolume 31\nVolume 32\nVolume 33\nVolume 34\nVolume 35\nVolume 36\nVolume 37\nVolume 38\nVolume 39\nVolume 40\nVolume 41\nVolume 42\nVolume 43\nVolume 44\nVolume 45\nVolume 46\nVolume 47\nVolume 48\nVolume 49\nVolume 50\nVolume 51\nVolume 52\nVolume 53\nVolume 54\nVolume 55\nVolume 56\nVolume 57\nVolume 58\nVolume 59\nVolume 60\nVolume 61\nVolume 62\nVolume 63\nVolume 64\nVolume 65\nVolume 66\nVolume 67\nVolume 68\nVolume 69\nVolume 70\nVolume 71\nVolume 72\nVolume 73\nVolume 74\nVolume 75\nVolume 76\nVolume 77\nVolume 78\nVolume 79\nVolume 80\nVolume 81\nVolume 82\nVolume 83\nVolume 84\nVolume 85\nVolume 86\nVolume 87\nVolume 88\nVolume 89\nVolume 90\nVolume 91\nVolume 92\nVolume 93\nVolume 94\nVolume 95\nVolume 96\ ...

# %%
tag = 'div'
class_name = {"class": "mw-parser-output"}
results = soup.find_all(tag, class_name)
print('Type of the variable \'article\':', article.__class__.__name__)
# Out:
# Type of the variable 'article': Tag

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
print(re.sub(r'\n\n+','\n', article.text)[:1000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18924/2063720133.py in <module>
# ----> 1 print(re.sub(r'\n\n+','\n', article.text)[:1000])
#
# NameError: name 're' is not defined

# %% [markdown]
# ### Find the links in the text

# %%
tag ='a'

tag_list = [t.get('href') for t in article.find_all(tag)]
tag_list
# Out:
# ['https://mangaplus.shueisha.co.jp/viewer/1000486',
#  'https://mangaplus.shueisha.co.jp/viewer/1012878',
#  'https://www.crunchyroll.com/one-piece/episode-1-im-luffy-the-man-whos-gonna-be-king-of-the-pirates-650673',
#  'https://www.crunchyroll.com/one-piece/episode-1013-yamatos-past-the-man-who-came-for-an-emperor-of-the-sea-825467',
#  '#portal_content-0',
#  '#portal_content-1',
#  '#portal_content-2',
#  '#portal_content-3',
#  '#portal_content-4',
#  '#portal_content-5',
#  'https://static.wikia.nocookie.net/onepiece/images/6/6b/Slide_1_preview.png/revision/latest?cb=20210905184758',
#  'https://static.wikia.nocookie.net/onepiece/images/b/b8/Slide_2_preview.png/revision/latest?cb=20171010172517',
#  'https://static.wikia.nocookie.net/onepiece/images/d/d7/Slide_3_preview.png/revision/latest?cb=20220215140036',
#  'https://static.wikia.nocookie.net/onepiece/images/1/1d/Slide_4_preview.png/revision/latest?cb=20180307050112',
#  'https://static.wikia.nocookie.net/onepiece/images/d/d7/Slide_5_preview.png/revision/latest?cb=20190818203303',
#  'https://onepiece.fandom.com/wiki/Template:Slider/Slide_1?action=edit',
#  '#portal_vtab-1',
#  '#portal_vtab-2',
#  '#portal_vtab-3',
#  '#portal_vtab-4',
#  '#portal_vtab-5',
#  '#portal_vtab-6',
#  '/wiki/Monkey_D._Luffy',
#  '/wiki/Straw_Hat_Pirates',
#  '/wiki/List_of_Canon_Characters',
#  '/wiki/List_of_Non-Canon_Characters',
#  '/wiki/Pirates',
#  '/wiki/Marines',
#  '/wiki/Category:Races_and_Tribes',
#  '/wiki/Category:Antagonists',
#  '/wiki/Category:Occupations',
#  '/wiki/Category:Races_and_Tribes',
#  '/wiki/Category:Technology',
#  '/wiki/Animal_Species',
#  '/wiki/Grand_Line',
#  '/wiki/Category:Islands',
#  '/wiki/East_Blue',
#  '/wiki/New_World',
#  '/wiki/Marines',
#  '/wiki/Pirates',
#  '/wiki/Seven_Warlords_of_the_Sea',
#  '/wiki/Four_Emperors',
#  '/wiki/World_Government',
#  '/wiki/Revolutionary_Army',
#  '/wiki/Devil_Fruit',
#  '/wiki/Gomu_Gomu_no_Mi',
#  '/wiki/Paramecia',
#  '/wiki/Zoan',
#  '/wiki/Logia',
#  '/wiki/Artificial_Devil_Fruit',
#  '/wiki/Devil_Fruit#Natural_Devil_Fruits',
#  '/wiki/SMILE',
#  '/wiki/Category:Non-Canon_Devil_Fruits',
#  '/wiki/One_Piece_Wiki:Guidebook',
#  '/wiki/One_Piece_Wiki:Guidebook/Referencing_Information',
#  '/wiki/User_blog:Leviathan_89/What_you_have_to_know_about_signatures',
#  '/wiki/One_Piece_Wiki:FAQ',
#  '/wiki/One_Piece_Wiki:Wiki_Crews',
#  '/wiki/Category:Chapter_Stubs',
#  '/wiki/Category:Episode_Stubs',
#  'https://discord.gg/6Ee6Anm',
#  'https://onepiece.fandom.com/wiki/Template:Slider/Slide_2?action=edit',
#  '#portal_vtab-1',
#  '#portal_vtab-2',
#  '#portal_vtab-3',
#  '#portal_vtab-4',
#  '#portal_vtab-5',
#  '/wiki/Chapters_and_Volumes/Volume_1-10',
#  '/wiki/Chapters_and_Volumes/Volume_11-20',
#  '/wiki/Chapters_and_Volumes/Volume_21-30',
#  '/wiki/Chapters_and_Volumes/Volume_31-40',
#  '/wiki/Chapters_and_Volumes/Volume_41-50',
#  '/wiki/Chapters_and_Volumes/Volume_51-60',
#  '/wiki/Chapters_and_Volumes/Volume_61-70',
#  '/wiki/Chapters_and_Volumes/Volume_71-80',
#  '/wiki/Chapters_and_Volumes/Volume_81-90',
#  '/wiki/Chapters_and_Volumes/Volume_91-100',
#  '/wiki/Chapters_and_Volumes/Volume_101-110',
#  '/wiki/Chapters_and_Volumes/Special',
#  '/wiki/SBS_Volume_4',
#  '/wiki/SBS_Volume_5',
#  '/wiki/SBS_Volume_6',
#  '/wiki/SBS_Volume_7',
#  '/wiki/SBS_Volume_8',
#  '/wiki/SBS_Volume_9',
#  '/wiki/SBS_Volume_10',
#  '/wiki/SBS_Volume_11',
#  '/wiki/SBS_Volume_12',
#  '/wiki/SBS_Volume_13',
#  '/wiki/SBS_Volume_14',
#  '/wiki/SBS_Volume_15',
#  '/wiki/SBS_Volume_16',
#  '/wiki/SBS_Volume_17',
#  '/wiki/SBS_Volume_18',
#  '/wiki/SBS_Volume_19',
#  '/wiki/SBS_Volume_20',
#  '/wiki/SBS_Volume_21',
#  '/wiki/SBS_Volume_22',
#  '/wiki/SBS_Volume_23',
#  '/wiki/SBS_Volume_24',
#  '/wiki/SBS_Volume_25',
#  '/wiki/SBS_Volume_26',
#  '/wiki/SBS_Volume_27',
#  '/wiki/SBS_Volume_28',
#  '/wiki/SBS_Volume_29',
#  '/wiki/SBS_Volume_30',
#  '/wiki/SBS_Volume_31',
#  '/wiki/SBS_Volume_32',
#  '/wiki/SBS_Volume_33',
#  '/wiki/SBS_Volume_34',
#  '/wiki/SBS_Volume_35',
#  '/wiki/SBS_Volume_36',
#  '/wiki/SBS_Volume_37',
#  '/wiki/SBS_Volume_38',
#  '/wiki/SBS_Volume_39',
#  '/wiki/SBS_Volume_40',
#  '/wiki/SBS_Volume_41',
#  '/wiki/SBS_Volume_42',
#  '/wiki/SBS_Volume_43',
#  '/wiki/SBS_Volume_44',
#  '/wiki/SBS_Volume_45',
#  '/wiki/SBS_Volume_46',
#  '/wiki/SBS_Volume_47',
#  '/wiki/SBS_Volume_48',
#  '/wiki/SBS_Volume_49',
#  '/wiki/SBS_Volume_50',
#  '/wiki/SBS_Volume_51',
#  '/wiki/SBS_Volume_52',
#  '/wiki/SBS_Volume_53',
#  '/wiki/SBS_Volume_54',
#  '/wiki/SBS_Volume_55',
#  '/wiki/SBS_Volume_56',
#  '/wiki/SBS_Volume_57',
#  '/wiki/SBS_Volume_58',
#  '/wiki/SBS_Volume_59',
#  '/wiki/SBS_Volume_60',
#  '/wiki/SBS_Volume_61',
#  '/wiki/SBS_Volume_62',
#  '/wiki/SBS_Volume_63',
#  '/wiki/SBS_Volume_64',
#  '/wiki/SBS_Volume_65',
#  '/wiki/SBS_Volume_66',
#  '/wiki/SBS_Volume_67',
#  '/wiki/SBS_Volume_68',
#  '/wiki/SBS_Volume_69',
#  '/wiki/SBS_Volume_70',
#  '/wiki/SBS_Volume_71',
#  '/wiki/SBS_Volume_72',
#  '/wiki/SBS_Volume_73',
#  '/wiki/SBS_Volume_74',
#  '/wiki/SBS_Volume_75',
#  '/wiki/SBS_Volume_76',
#  '/wiki/SBS_Volume_77',
#  '/wiki/SBS_Volume_78',
#  '/wiki/SBS_Volume_79',
#  '/wiki/SBS_Volume_80',
#  '/wiki/SBS_Volume_81',
#  '/wiki/SBS_Volume_82',
#  '/wiki/SBS_Volume_83',
#  '/wiki/SBS_Volume_84',
#  '/wiki/SBS_Volume_85',
#  '/wiki/SBS_Volume_86',
#  '/wiki/SBS_Volume_87',
#  '/wiki/SBS_Volume_88',
#  '/wiki/SBS_Volume_89',
#  '/wiki/SBS_Volume_90',
#  '/wiki/SBS_Volume_91',
#  '/wiki/SBS_Volume_92',
#  '/wiki/SBS_Volume_93',
#  '/wiki/SBS_Volume_94',
#  '/wiki/SBS_Volume_95',
#  '/wiki/SBS_Volume_96',
#  '/wiki/SBS_Volume_97',
#  '/wiki/SBS_Volume_98',
#  '/wiki/SBS_Volume_99',
#  '/wiki/SBS_Volume_100',
#  '/wiki/SBS_Volume_101',
#  '/wiki/Author%27s_Notes#Volume_1',
#  '/wiki/Author%27s_Notes#Volume_2',
#  '/wiki/Author%27s_Notes#Volume_3',
#  '/wiki/Author%27s_Notes#Volume_4',
#  '/wiki/Author%27s_Notes#Volume_5',
#  '/wiki/Author%27s_Notes#Volume_6',
#  '/wiki/Author%27s_Notes#Volume_7',
#  '/wiki/Author%27s_Notes#Volume_8',
#  '/wiki/Author%27s_Notes#Volume_9',
#  '/wiki/Author%27s_Notes#Volume_10',
#  '/wiki/Author%27s_Notes#Volume_11',
#  '/wiki/Author%27s_Notes#Volume_12',
#  '/wiki/Author%27s_Notes#Volume_13',
#  '/wiki/Author%27s_Notes#Volume_14',
#  '/wiki/Author%27s_Notes#Volume_15',
#  '/wiki/Author%27s_Notes#Volume_16',
#  '/wiki/Author%27s_Notes#Volume_17',
#  '/wiki/Author%27s_Notes#Volume_18',
#  '/wiki/Author%27s_Notes#Volume_19',
#  '/wiki/Author%27s_Notes#Volume_20',
#  '/wiki/Author%27s_Notes#Volume_21',
#  '/wiki/Author%27s_Notes#Volume_22',
#  '/wiki/Author%27s_Notes#Volume_23',
#  '/wiki/Author%27s_Notes#Volume_24',
#  '/wiki/Author%27s_Notes#Volume_25',
#  '/wiki/Author%27s_Notes#Volume_26',
#  '/wiki/Author%27s_Notes#Volume_27',
#  '/wiki/Author%27s_Notes#Volume_28',
#  '/wiki/Author%27s_Notes#Volume_29',
#  '/wiki/Author%27s_Notes#Volume_30',
#  '/wiki/Author%27s_Notes#Volume_31',
#  '/wiki/Author%27s_Notes#Volume_32',
#  '/wiki/Author%27s_Notes#Volume_33',
#  '/wiki/Author%27s_Notes#Volume_34',
#  '/wiki/Author%27s_Notes#Volume_35',
#  '/wiki/Author%27s_Notes#Volume_36',
#  '/wiki/Author%27s_Notes#Volume_37',
#  '/wiki/Author%27s_Notes#Volume_38',
#  '/wiki/Author%27s_Notes#Volume_39',
#  '/wiki/Author%27s_Notes#Volume_40',
#  '/wiki/Author%27s_Notes#Volume_41',
#  '/wiki/Author%27s_Notes#Volume_42',
#  '/wiki/Author%27s_Notes#Volume_43',
#  '/wiki/Author%27s_Notes#Volume_44',
#  '/wiki/Author%27s_Notes#Volume_45',
#  '/wiki/Author%27s_Notes#Volume_46',
#  '/wiki/Author%27s_Notes#Volume_47',
#  '/wiki/Author%27s_Notes#Volume_48',
#  '/wiki/Author%27s_Notes#Volume_49',
#  '/wiki/Author%27s_Notes#Volume_50',
#  '/wiki/Author%27s_Notes#Volume_51',
#  '/wiki/Author%27s_Notes#Volume_52',
#  '/wiki/Author%27s_Notes#Volume_53',
#  '/wiki/Author%27s_Notes#Volume_54',
#  '/wiki/Author%27s_Notes#Volume_55',
#  '/wiki/Author%27s_Notes#Volume_56',
#  '/wiki/Author%27s_Notes#Volume_57',
#  '/wiki/Author%27s_Notes#Volume_58',
#  '/wiki/Author%27s_Notes#Volume_59',
#  '/wiki/Author%27s_Notes#Volume_60',
#  '/wiki/Author%27s_Notes#Volume_61',
#  '/wiki/Author%27s_Notes#Volume_62',
#  '/wiki/Author%27s_Notes#Volume_63',
#  '/wiki/Author%27s_Notes#Volume_64',
#  '/wiki/Author%27s_Notes#Volume_65',
#  '/wiki/Author%27s_Notes#Volume_66',
#  '/wiki/Author%27s_Notes#Volume_67',
#  '/wiki/Author%27s_Notes#Volume_68',
#  '/wiki/Author%27s_Notes#Volume_69',
#  '/wiki/Author%27s_Notes#Volume_70',
#  '/wiki/Author%27s_Notes#Volume_71',
#  '/wiki/Author%27s_Notes#Volume_72',
#  '/wiki/Author%27s_Notes#Volume_73',
#  '/wiki/Author%27s_Notes#Volume_74',
#  '/wiki/Author%27s_Notes#Volume_75',
#  '/wiki/Author%27s_Notes#Volume_76',
#  '/wiki/Author%27s_Notes#Volume_77',
#  '/wiki/Author%27s_Notes#Volume_78',
#  '/wiki/Author%27s_Notes#Volume_79',
#  '/wiki/Author%27s_Notes#Volume_80',
#  '/wiki/Author%27s_Notes#Volume_81',
#  '/wiki/Author%27s_Notes#Volume_82',
#  '/wiki/Author%27s_Notes#Volume_83',
#  '/wiki/Author%27s_Notes#Volume_84',
#  '/wiki/Author%27s_Notes#Volume_85',
#  '/wiki/Author%27s_Notes#Volume_86',
#  '/wiki/Author%27s_Notes#Volume_87',
#  '/wiki/Author%27s_Notes#Volume_88',
#  '/wiki/Author%27s_Notes#Volume_89',
#  '/wiki/Author%27s_Notes#Volume_90',
#  '/wiki/Author%27s_Notes#Volume_91',
#  '/wiki/Author%27s_Notes#Volume_92',
#  '/wiki/Author%27s_Notes#Volume_93',
#  '/wiki/Author%27s_Notes#Volume_94',
#  '/wiki/Author%27s_Notes#Volume_95',
#  '/wiki/Author%27s_Notes#Volume_96',
#  '/wiki/Author%27s_Notes#Volume_97',
#  '/wiki/Author%27s_Notes#Volume_98',
#  '/wiki/Author%27s_Notes#Volume_99',
#  '/wiki/Author%27s_Notes#Volume_100',
#  '/wiki/Author%27s_Notes#Volume_101',
#  '/wiki/Author%27s_Notes#Wanted.21',
#  '/wiki/Author%27s_Notes#STRONG_WORLD',
#  '/wiki/Author%27s_Notes#One_Piece_Rainbow.21_Official_Animation_Guide_Book',
#  '/wiki/Author%27s_Notes#One_Piece_White.21',
#  '/wiki/Author%27s_Notes#Volume_1000',
#  '/wiki/Author%27s_Notes#One_Piece_500_Quiz_Book',
#  '/wiki/Author%27s_Notes#Volume_777',
#  '/wiki/One_Piece_Red:_Grand_Characters',
#  '/wiki/One_Piece_Blue:_Grand_Data_File',
#  '/wiki/One_Piece_Yellow:_Grand_Elements',
#  '/wiki/One_Piece_Green:_Secret_Pieces',
#  '/wiki/One_Piece_Blue_Deep:_Characters_World',
#  '/wiki/Vivre_Card_-_One_Piece_Visual_Dictionary',
#  '/wiki/Buggy%27s_Crew:_After_the_Battle!',
#  '/wiki/Diary_of_Coby-Meppo',
#  '/wiki/Jango%27s_Dance_Paradise',
#  '/wiki/Hatchan%27s_Sea-Floor_Stroll',
#  '/wiki/Wapol%27s_Omnivorous_Hurrah',
#  '/wiki/Ace%27s_Great_Blackbeard_Search',
#  '/wiki/Gedatsu%27s_Accidental_Blue-Sea_Life',
#  '/wiki/Miss_Goldenweek%27s_%22Operation:_Meet_Baroque_Works%22',
#  '/wiki/Enel%27s_Great_Space_Operations',
#  '/wiki/CP9%27s_Independent_Report',
#  '/wiki/Straw_Hat%27s_Separation_Serial',
#  '/wiki/From_the_Decks_of_the_World',
#  '/wiki/Caribou%27s_Kehihihihi_in_the_New_World',
#  '/wiki/Solo_Journey_of_Jinbe,_Knight_of_the_Sea',
#  '/wiki/From_the_Decks_of_the_World:_The_500,000,000_Man_Arc',
#  '/wiki/The_Stories_of_the_Self-Proclaimed_Straw_Hat_Grand_Fleet',
#  '/wiki/%22Gang%22_Bege%27s_Oh_My_Family',
#  'https://onepiece.fandom.com/wiki/Template:Slider/Slide_3?action=edit',
#  '#portal_vtab-1',
#  '#portal_vtab-2',
#  '#portal_vtab-3',
#  '#portal_vtab-4',
#  '#portal_vtab-5',
#  '#portal_vtab-6',
#  '/wiki/Episode_Guide/East_Blue_Saga',
#  '/wiki/Episode_Guide/Alabasta_Saga',
#  '/wiki/Episode_Guide/Sky_Island_Saga',
#  '/wiki/Episode_Guide/Water_7_Saga',
#  '/wiki/Episode_Guide/Thriller_Bark_Saga',
#  '/wiki/Episode_Guide/Summit_War_Saga',
#  '/wiki/Episode_Guide/Fishman_Island_Saga',
#  '/wiki/Episode_Guide/Dressrosa_Saga',
#  '/wiki/Episode_Guide/Four_Emperors_Saga',
#  '/wiki/One_Piece:_The_Movie',
#  '/wiki/Clockwork_Island_Adventure',
#  '/wiki/Chopper%27s_Kingdom_on_the_Island_of_Strange_Animals',
#  '/wiki/Dead_End_Adventure',
#  '/wiki/The_Cursed_Holy_Sword',
#  '/wiki/Baron_Omatsuri_and_the_Secret_Island',
#  '/wiki/The_Giant_Mechanical_Soldier_of_Karakuri_Castle',
#  '/wiki/Episode_of_Alabasta:_The_Desert_Princess_and_the_Pirates',
#  '/wiki/Episode_of_Chopper_Plus:_Bloom_in_Winter,_Miracle_Sakura',
#  '/wiki/One_Piece_Film:_Strong_World',
#  '/wiki/One_Piece_3D:_Straw_Hat_Chase',
#  '/wiki/One_Piece_Film:_Z',
#  '/wiki/One_Piece_Film:_Gold',
#  '/wiki/One_Piece:_Stampede',
#  '/wiki/One_Piece_Film:_Red',
#  '/wiki/Warship_Island_Arc',
#  '/wiki/Post-Alabasta_Arc',
#  '/wiki/Goat_Island_Arc',
#  '/wiki/Ruluka_Island_Arc',
#  '/wiki/G-8_Arc',
#  '/wiki/Ocean%27s_Dream_Arc',
#  '/wiki/Foxy%27s_Return_Arc',
#  '/wiki/Ice_Hunter_Arc',
#  '/wiki/Spa_Island_Arc',
#  '/wiki/Little_East_Blue_Arc',
#  '/wiki/Z%27s_Ambition_Arc',
#  '/wiki/Caesar_Retrieval_Arc',
#  '/wiki/Silver_Mine_Arc',
#  '/wiki/Marine_Rookie_Arc',
#  '/wiki/Cidre_Guild_Arc',
#  '/wiki/One_Piece_Soundtracks',
#  '/wiki/Movie_2_OST',
#  '/wiki/Movie_3_OST',
#  '/wiki/Movie_4_OST',
#  '/wiki/Movie_6_OST',
#  '/wiki/Movie_7_OST',
#  '/wiki/Movie_8_OST',
#  '/wiki/Movie_10_OST',
#  '/wiki/One_Piece_Film_Z_OST',
#  '/wiki/Episode_Special_1',
#  '/wiki/Episode_Special_2',
#  '/wiki/Episode_Special_3',
#  '/wiki/Episode_Special_4',
#  '/wiki/Episode_of_Nami',
#  '/wiki/Episode_of_Luffy',
#  '/wiki/Episode_of_Merry',
#  '/wiki/3D2Y',
#  '/wiki/Adventure_of_Nebulandia',
#  '/wiki/Episode_of_Sabo',
#  '/wiki/Glorious_Island',
#  '/wiki/Heart_of_Gold',
#  '/wiki/Episode_of_East_Blue',
#  '/wiki/Episode_of_Sky_Island',
#  '/wiki/We_Are!',
#  '/wiki/Believe',
#  '/wiki/Hikari_e',
#  '/wiki/BON_VOYAGE!',
#  '/wiki/Kokoro_no_Chizu',
#  '/wiki/Brand_New_World',
#  '/wiki/Crazy_Rainbow',
#  '/wiki/Jungle_P',
#  '/wiki/Share_the_World',
#  '/wiki/Kaze_wo_Sagashite',
#  '/wiki/One_day',
#  '/wiki/Fight_Together',
#  '/wiki/We_Go!',
#  '/wiki/Hands_Up!',
#  '/wiki/Wake_up!',
#  '/wiki/Hard_Knock_Days',
#  '/wiki/We_Can!',
#  '/wiki/Hope',
#  '/wiki/Super_Powers',
#  '/wiki/OVER_THE_TOP',
#  '/wiki/DREAMIN%27_ON',
#  '/wiki/PAINT',
#  'https://onepiece.fandom.com/wiki/Template:Slider/Slide_4?action=edit',
#  '#portal_vtab-1',
#  '#portal_vtab-2',
#  '#portal_vtab-3',
#  '#portal_vtab-4',
#  '#portal_vtab-5',
#  '#portal_vtab-6',
#  '#portal_vtab-7',
#  '#portal_vtab-8',
#  '#portal_vtab-9',
#  '/wiki/Monkey_D._Luffy',
#  '/wiki/Roronoa_Zoro',
#  '/wiki/Nami',
#  '/wiki/Usopp',
#  '/wiki/Sanji',
#  '/wiki/Tony_Tony_Chopper',
#  '/wiki/Nico_Robin',
#  '/wiki/Franky',
#  '/wiki/Brook',
#  '/wiki/Jinbe',
#  '/wiki/Shanks',
#  '/wiki/Koby',
#  '/wiki/Gaimon',
#  '/wiki/Kaya',
#  '/wiki/Johnny',
#  '/wiki/Yosaku',
#  '/wiki/Zeff',
#  '/wiki/Nojiko',
#  '/wiki/Bell-m%C3%A8re',
#  '/wiki/Higuma',
#  '/wiki/Alvida',
#  '/wiki/Morgan',
#  '/wiki/Helmeppo',
#  '/wiki/Buggy',
#  '/wiki/Kuro',
#  '/wiki/Krieg',
#  '/wiki/Gin',
#  '/wiki/Arlong',
#  '/wiki/Nefertari_Vivi',
#  '/wiki/Laboon',
#  '/wiki/Karoo',
#  '/wiki/Dorry',
#  '/wiki/Brogy',
#  '/wiki/Dalton',
#  '/wiki/Kureha',
#  '/wiki/Portgas_D._Ace',
#  '/wiki/Igaram',
#  '/wiki/Kohza',
#  '/wiki/Nefertari_Cobra',
#  '/wiki/Smoker',
#  '/wiki/Wapol',
#  '/wiki/Mikita',
#  '/wiki/Gem',
#  '/wiki/Marianne',
#  '/wiki/Galdino',
#  '/wiki/Bentham',
#  '/wiki/Zala',
#  '/wiki/Daz_Bonez',
#  '/wiki/Crocodile',
#  '/wiki/Mont_Blanc_Cricket',
#  '/wiki/Conis',
#  '/wiki/Pagaya',
#  '/wiki/Wyper',
#  '/wiki/Gan_Fall',
#  '/wiki/Aisa',
#  '/wiki/Montblanc_Noland',
#  '/wiki/Kalgara',
#  '/wiki/Bellamy',
#  '/wiki/Enel',
#  '/wiki/Satori',
#  '/wiki/Shura',
#  '/wiki/Gedatsu',
#  '/wiki/Ohm',
#  '/wiki/Iceburg',
#  '/wiki/Paulie',
#  '/wiki/Kokoro',
#  '/wiki/Galley-La_Company',
#  '/wiki/Franky_Family',
#  '/wiki/Rob_Lucci',
#  '/wiki/Kaku',
#  '/wiki/Jabra',
#  '/wiki/Blueno',
#  '/wiki/Kalifa',
#  '/wiki/Fukurou',
#  '/wiki/Kumadori',
#  '/wiki/Spandam',
#  '/wiki/Kuzan',
#  '/wiki/Foxy',
#  '/wiki/Charlotte_Lola',
#  '/wiki/Gekko_Moriah',
#  '/wiki/Hogback',
#  '/wiki/Absalom',
#  '/wiki/Perona',
#  '/wiki/Oars',
#  '/wiki/Ryuma',
#  '/wiki/Bartholomew_Kuma',
#  '/wiki/Keimi',
#  '/wiki/Pappug',
#  '/wiki/Hatchan',
#  '/wiki/Silvers_Rayleigh',
#  '/wiki/Worst_Generation',
#  '/wiki/Boa_Hancock',
#  '/wiki/Emporio_Ivankov',
#  '/wiki/Edward_Newgate',
#  '/wiki/Marco',
#  '/wiki/Duval',
#  '/wiki/Charlos',
#  '/wiki/Marshall_D._Teach',
#  '/wiki/Magellan',
#  '/wiki/Hannyabal',
#  '/wiki/Sakazuki',
#  '/wiki/Kuzan',
#  '/wiki/Borsalino',
#  '/wiki/Sentomaru',
#  '/wiki/Dracule_Mihawk',
#  '/wiki/Donquixote_Doflamingo',
#  '/wiki/Momonga',
#  '/wiki/Shirahoshi',
#  '/wiki/Neptune',
#  '/wiki/Surume',
#  '/wiki/Shyarly',
#  '/wiki/Trafalgar_D._Water_Law',
#  '/wiki/Kin%27emon',
#  '/wiki/Kozuki_Momonosuke',
#  '/wiki/Kurozumi_Kanjuro',
#  '/wiki/Chadros_Higelyges',
#  '/wiki/Bartolomeo',
#  '/wiki/Cavendish',
#  '/wiki/Rebecca',
#  '/wiki/Kyros',
#  '/wiki/Riku_Doldo_III',
#  '/wiki/Sabo',
#  '/wiki/Caribou',
#  '/wiki/Hody_Jones',
#  '/wiki/Vander_Decken_IX',
#  '/wiki/Hyouzou',
#  '/wiki/Caesar_Clown',
#  '/wiki/Monet',
#  '/wiki/Vergo',
#  '/wiki/Trebol',
#  '/wiki/Diamante',
#  '/wiki/Pica',
#  '/wiki/Senor_Pink',
#  '/wiki/Buffalo',
#  '/wiki/Baby_5',
#  '/wiki/Issho',
#  '/wiki/Raizo',
#  '/wiki/Carrot',
#  '/wiki/Pedro',
#  '/wiki/Wanda',
#  '/wiki/Inuarashi',
#  '/wiki/Nekomamushi',
#  '/wiki/Pekoms',
#  '/wiki/Zunesha',
#  '/wiki/Capone_Bege',
#  '/wiki/Kaidou',
#  '/wiki/Jack',
#  '/wiki/Charlotte_Linlin',
#  '/wiki/Vinsmoke_Judge',
#  '/wiki/Charlotte_Katakuri',
#  '/wiki/Charlotte_Pudding',
#  '/wiki/Charlotte_Cracker',
#  '/wiki/Charlotte_Smoothie',
#  '/wiki/Charlotte_Perospero',
#  '/wiki/Kozuki_Oden',
#  '/wiki/Kozuki_Hiyori',
#  '/wiki/Kikunojo',
#  '/wiki/Denjiro',
#  '/wiki/Ashura_Doji',
#  '/wiki/Kawamatsu',
#  '/wiki/Shinobu',
#  '/wiki/Hyogoro',
#  '/wiki/Shimotsuki_Yasuie',
#  '/wiki/Yamato',
#  '/wiki/King',
#  '/wiki/Queen',
#  '/wiki/Who%27s-Who',
#  '/wiki/Black_Maria',
#  '/wiki/Sasaki',
#  '/wiki/Page_One',
#  '/wiki/Ulti',
#  '/wiki/Scratchmen_Apoo',
#  '/wiki/Numbers',
#  'https://onepiece.fandom.com/wiki/Template:Slider/Slide_5?action=edit',
#  '#portal_vtab-1',
#  '#portal_vtab-2',
#  '#portal_vtab-3',
#  '/wiki/One_Piece:_Stampede',
#  '/wiki/One_Piece_Volume_10089',
#  '/wiki/Cidre_Guild_Arc',
#  '/wiki/Monkey_D._Luffy',
#  '/wiki/Trafalgar_D._Water_Law',
#  '/wiki/Sabo',
#  '/wiki/Boa_Hancock',
#  '/wiki/Buggy',
#  '/wiki/Smoker',
#  '/wiki/Rob_Lucci',
#  '/wiki/Crocodile',
#  '/wiki/Douglas_Bullet',
#  '/wiki/Buena_Festa',
#  '/wiki/Donald_Moderate',
#  '/wiki/Ann',
#  '/wiki/Cidre',
#  '/wiki/Guarana',
#  '/wiki/Ginger',
#  '/wiki/Gol_D._Roger',
#  '/wiki/Pirates_Festival',
#  '/wiki/Delta_Island',
#  '/wiki/Gasha_Gasha_no_Mi',
#  '/wiki/Bijo_Bijo_no_Mi',
#  '/wiki/Cidre_Guild',
#  'https://community.fandom.com/wiki/Help:Contents',
#  '/wiki/One_Piece_Wiki:Guidebook',
#  '/wiki/One_Piece_Wiki:FAQ',
#  '/wiki/One_Piece_Wiki:Guidebook/User_Rights',
#  '/wiki/Special:Forum',
#  '/wiki/Blog:Recent_posts',
#  'https://onepiece.fandom.com/d/f?sort=latest',
#  'https://discord.gg/MrhkyUZ',
#  '/wiki/One_Piece_(Manga)',
#  '/wiki/One_Piece_(Anime)',
#  'https://community.fandom.com/wiki/Help:Contents',
#  '/wiki/Eiichiro_Oda',
#  '/wiki/One_Piece_Wiki:Spoiler_Rules',
#  '/wiki/Artificial_Devil_Fruit',
#  '/wiki/Devil_Fruit',
#  '/wiki/Vegapunk',
#  '/wiki/SMILE',
#  '/wiki/Caesar_Clown',
#  '/wiki/Artificial_Devil_Fruit',
#  '/wiki/Marshall_D._Teach',
#  '/wiki/Template:Current_Events/Manga',
#  '/wiki/Chapter_1044',
#  '/wiki/Monkey_D._Luffy',
#  '/wiki/Five_Elders',
#  '/wiki/Nika',
#  '/wiki/Gomu_Gomu_no_Mi',
#  '/wiki/Kozuki_Hiyori',
#  '/wiki/Kurozumi_Orochi',
#  '/wiki/Kazenbo',
#  '/wiki/Kaidou',
#  '/wiki/Gomu_Gomu_no_Mi/Gear_Fifth_Techniques',
#  '/wiki/Chapter_1044',
#  '/wiki/Template:Current_Events/Anime',
#  '/wiki/Episode_1013',
#  '/wiki/Episode_1013',
#  '/wiki/Episode_1014',
#  '/wiki/User:Gomuking',
#  '/wiki/User:Gomuking',
#  '/wiki/User_blog:Gomuking/how_strong_do_you_think_game_luffy_is',
#  '/wiki/User_blog:Gomuking/how_strong_do_you_think_game_luffy_is',
#  '/wiki/User:OdaFan',
#  '/wiki/User:OdaFan',
#  '/wiki/User_blog:OdaFan/Ton_Ton_fruit_is_the_most_dangerous_fruit',
#  '/wiki/User_blog:OdaFan/Ton_Ton_fruit_is_the_most_dangerous_fruit',
#  '/wiki/User:JackSpicer305',
#  '/wiki/User:JackSpicer305',
#  '/wiki/User_blog:JackSpicer305/The_Mishandling_of_the_Nine_Red_Scabbards',
#  '/wiki/User_blog:JackSpicer305/The_Mishandling_of_the_Nine_Red_Scabbards',
#  '/wiki/User:Shonennarutoz',
#  '/wiki/User:Shonennarutoz',
#  '/wiki/User_blog:Shonennarutoz/Naruto_or_One_piece',
#  '/wiki/User_blog:Shonennarutoz/Naruto_or_One_piece',
#  '/wiki/User:Gomuking',
#  '/wiki/User:Gomuking',
#  '/wiki/User_blog:Gomuking/who%27s_techniqes_are_better',
#  '/wiki/User_blog:Gomuking/who%27s_techniqes_are_better',
#  '/wiki/User:Gomuking',
#  '/wiki/User:Gomuking',
#  '/wiki/User_blog:Gomuking/who%27s_fire_is_better',
#  '/wiki/User_blog:Gomuking/who%27s_fire_is_better',
#  '/wiki/Blog:Recent_Blog_Posts',
#  'http://www.onepieceofficial.com/',
#  '/wiki/FUNimation',
#  'http://www.shonenjump.com/e/index.html',
#  'http://www.viz.com/one-piece',
#  'http://www.one-piece.com',
#  'http://www.j-onepiece.com/',
#  'http://www.toei-anim.co.jp/tv/onep/',
#  'http://avex.jp/onepiece/',
#  'http://apforums.net/forum.php',
#  'http://www.onepiecepodcast.com/',
#  'http://www.reddit.com/r/OnePiece/',
#  'https://worstgen.alwaysdata.net/forum/',
#  'https://shipoffools.fandom.com/wiki/',
#  'https://www.facebook.com/OnePieceWikia',
#  'https://twitter.com/opwikia',
#  'https://www.youtube.com/channel/UC5C2Nn24Q3HLzW-6iuG-QLQ',
#  'https://jump.fandom.com/wiki/',
#  'https://shipoffools.fandom.com/wiki/',
#  'https://oproleplaying.fandom.com/wiki/',
#  'https://ajin.fandom.com/wiki/',
#  'https://akamegakill.fandom.com/wiki/',
#  'https://aonoexorcist.fandom.com/wiki/',
#  'https://aread.fandom.com/wiki/',
#  'https://ansatsukyoshitsu.fandom.com/wiki/',
#  'https://attackontitan.fandom.com/wiki/',
#  'https://bastard.fandom.com/wiki/',
#  'https://beelzebub.fandom.com/wiki/',
#  'https://berserk.fandom.com/wiki/',
#  'https://blackbullet.fandom.com/wiki/',
#  'https://bleach.fandom.com/wiki/',
#  'https://busterkeel.fandom.com/wiki/',
#  'https://chihayafuru.fandom.com/wiki/',
#  'https://codegeass.fandom.com/wiki/',
#  'https://coppelion.fandom.com/wiki/',
#  'https://dragonballuniverse.fandom.com/wiki/',
#  'https://dragonball.fandom.com/wiki/',
#  'https://dragonsrioting.fandom.com/wiki/',
#  'https://drifters.fandom.com/wiki/',
#  'https://fairytail.fandom.com/wiki/',
#  'https://fire-force.fandom.com/wiki/',
#  'https://fushigiyuugi.fandom.com/wiki/',
#  'https://ghost-hunt.fandom.com/wiki/',
#  'https://godofhighschool.fandom.com/wiki/',
#  'https://guiltycrown.fandom.com/wiki/Guilty_Crown_Wiki',
#  'https://hardcorelevelingwarrior.fandom.com/wiki/',
#  'https://dendro.fandom.com/wiki/',
#  'https://jackals.fandom.com/wiki/',
#  'https://jigokuraku.fandom.com/wiki/',
#  'https://k-project.fandom.com/wiki/',
#  'https://kingdom.fandom.com/wiki/',
#  'https://kongoubanchou.fandom.com/wiki/',
#  'https://lessa.fandom.com/wiki/',
#  'https://magi.fandom.com/wiki/',
#  'https://ancientmagusbride.fandom.com/wiki/',
#  'https://medakabox.fandom.com/wiki/',
#  'https://myheroacademia.fandom.com/wiki/',
#  'https://nanatsu-no-taizai.fandom.com/wiki/',
#  'https://naruto.fandom.com/wiki/',
#  'https://noblesse.fandom.com/wiki/',
#  'https://opartshunter.fandom.com/wiki/',
#  'https://onepunchman.fandom.com/wiki/',
#  'https://overlordmaruyama.fandom.com/wiki/',
#  'https://owarinoseraph.fandom.com/wiki/',
#  'https://mochijun.fandom.com/wiki/',
#  'https://psyren.fandom.com/wiki/',
#  'https://ravemaster.fandom.com/wiki/',
#  'https://saikikusuo-no-psinan.fandom.com/wiki/',
#  'https://shamankingflowers.fandom.com/wiki/',
#  'https://shinmaimaou.fandom.com/wiki/',
#  'https://shokugekinosoma.fandom.com/wiki/',
#  'https://souleater.fandom.com/wiki/',
#  'https://tensura.fandom.com/wiki/',
#  'https://terraformars.fandom.com/wiki/',
#  'https://thebreaker.fandom.com/wiki/',
#  'https://arslansenki.fandom.com/wiki/',
#  'https://yakusokunoneverland.fandom.com/wiki/',
#  'https://shield-hero.fandom.com/wiki/',
#  'https://toriko.fandom.com/wiki/',
#  'https://trump-webtoon.fandom.com/wiki/',
#  'https://worldtrigger.fandom.com/wiki/',
#  'https://yokokuhan.fandom.com/wiki/',
#  '/wiki/Saru',
#  '/wiki/Real-Life_Timeline',
#  '/wiki/Aim!_The_King_of_Belly',
#  '/wiki/Real-Life_Timeline',
#  '/wiki/Episode_187',
#  '/wiki/Episode_188',
#  '/wiki/Real-Life_Timeline',
#  '/wiki/Chapter_360',
#  '/wiki/Real-Life_Timeline',
#  '/wiki/Episode_444',
#  '/wiki/Real-Life_Timeline',
#  '/wiki/Episode_967',
#  '/wiki/Episode_Guide',
#  '/wiki/One_Piece_(Manga)',
#  '/wiki/Chapters_and_Volumes',
#  '/wiki/One_Piece_Movies',
#  '/wiki/List_of_Locations',
#  '/wiki/World_Timeline',
#  '/wiki/Category:Society_and_Culture',
#  '/wiki/List_of_Canon_Characters',
#  '/wiki/Animal_Species',
#  '/wiki/One_Piece_Merchandise',
#  '/wiki/One_Piece_Voice_Actors',
#  '/wiki/Category:One_Piece_International',
#  '/wiki/Template:Releases',
#  '/wiki/Template:Releases',
#  'https://static.wikia.nocookie.net/onepiece/images/b/b3/Volume_101.png/revision/latest?cb=20211122095619',
#  '/wiki/Volume_101',
#  'https://static.wikia.nocookie.net/onepiece/images/9/9d/Log_Wanokuni.png/revision/latest?cb=20220320010748',
#  '/wiki/Home_Video_Releases/Seasons_16-20#Season_20',
#  'https://static.wikia.nocookie.net/onepiece/images/c/cd/Viz_Current_Volume.png/revision/latest?cb=20220131010759',
#  '/wiki/Volume_99',
#  'https://static.wikia.nocookie.net/onepiece/images/9/9d/Season_11_Voyage_7_cover.png/revision/latest?cb=20220131013001',
#  '/wiki/FUNimation/Seasons_10-12#Season_11',
#  '/wiki/Montblanc_Noland',
#  '/wiki/Pumpkins',
#  '/wiki/Jaya',
#  '/wiki/Arabasta',
#  '/wiki/Arabasta',
#  '/wiki/Cavendish',
#  '/wiki/Mythbusters',
#  'https://twitter.com/opwikia',
#  'http://bit.ly/Wikia-OnePiece-GooglePlay',
#  'http://bit.ly/Wikia-OnePiece-Apple',
#  '/wiki/MediaWiki:Uploadtext',
#  '/wiki/One_Piece_Wiki:Research_Crew',
#  'https://mangaplus.shueisha.co.jp/titles/100020',
#  'https://www.viz.com/shonenjump/chapters/one-piece',
#  'https://discord.gg/MrhkyUZ',
#  '/wiki/Forum:Revamping_Featured_Articles',
#  '/wiki/One_Piece_Wiki:Separate_Volume_Pages_Project',
#  '/wiki/One_Piece_Wiki:Categorization_Fixing_Project',
#  '/wiki/Forum:Changing_the_Purpose_of_this_Forum',
#  '/wiki/User:Adv193',
#  '/wiki/Forum:More_Category_Issues',
#  '/wiki/Special:Contributions/Tokina8937',
#  '/wiki/Forum:Videos,_Timestamps_and_MP3s',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Forum:Tabs_changes',
#  '/wiki/User:Leviathan_89',
#  '/wiki/Forum:Trivia_on_Chapter_and_Episode_pages',
#  '/wiki/User:Rhavkin',
#  '/wiki/Forum:Conjectural_Portrait_Guidelines',
#  '/wiki/User:Nightmare_Pirates',
#  '/wiki/Forum:Weapon_Usage_Categories',
#  '/wiki/Forum:Removing_Movies_and_Specials_From_Character_Histories',
#  '/wiki/Forum:Allies_Sections_on_Group_Galleries',
#  '/wiki/Talk:Gomu_Gomu_no_Mi',
#  '/wiki/User:Sarutobii2',
#  '/wiki/Category_talk:Volume_Chapter_Images',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Category_talk:Infobox_Templates',
#  '/wiki/User:Montblanc_Noland',
#  '/wiki/File_talk:Narikabura_Arrow.png',
#  '/wiki/User:Dragonus_Nesha',
#  '/wiki/Talk:Marshall_D._Teach',
#  '/wiki/User:Marco_1907',
#  '/wiki/Category_talk:Characters_by_Position',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Category_talk:Military_Forces',
#  '/wiki/User:Montblanc_Noland',
#  '/wiki/Talk:Zombie',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Talk:Funimation/Episode_List_and_DVD_Releases',
#  '/wiki/User:Kaido_King_of_the_Beasts',
#  '/wiki/Talk:Arabasta_Kingdom',
#  '/wiki/Special:Contributions/Ranafor',
#  '/wiki/Talk:Foods',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Talk:Maki_Maki_no_Mi',
#  '/wiki/User:Dragonus_Nesha',
#  '/wiki/Template_talk:Straw_Hat_Pirates_Gallery',
#  '/wiki/User:Dragonus_Nesha',
#  '/wiki/Category_talk:Conjectural_Portraits',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Talk:One_Piece_1000_Logs',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Talk:Onigashima',
#  '/wiki/User:Rgilbert27',
#  '/wiki/One_Piece_Wiki_talk:Image_Crew',
#  '/wiki/User:Kaido_King_of_the_Beasts',
#  '/wiki/Talk:Swordsman',
#  '/wiki/User:Rgilbert27',
#  '/wiki/File_talk:Monkey_D._Luffy_Portrait.png',
#  '/wiki/User:Kaido_King_of_the_Beasts',
#  '/wiki/Talk:One_Piece_10th_Treasures',
#  '/wiki/User:Leviathan_89',
#  '/wiki/Talk:List_of_volumes_released_in_Latin_America',
#  '/wiki/User:Rgilbert27',
#  '/wiki/Talk:Page_One',
#  '/wiki/User:Dragonus_Nesha',
#  '/wiki/Template_talk:Char_Box',
#  '/wiki/User:Leviathan_89',
#  '/wiki/Talk:Brontosaurus',
#  '/wiki/User:Dragonus_Nesha',
#  '/wiki/Talk:Bustercall_Project',
#  '/wiki/User:Awaikage',
#  '/wiki/Template_talk:ChapterPages',
#  '/wiki/User:Leviathan_89',
#  '/wiki/Talk:One_Piece_Rap',
#  '/wiki/User:Kaido_King_of_the_Beasts',
#  '/wiki/Talk:Amber_Lead',
#  '/wiki/User:Rhavkin',
#  '/wiki/Talk:Chapter_977',
#  '/wiki/One_Piece_Wiki_talk:Guidebook/Spoiler_Rules',
#  '/wiki/Talk:Poneglyph',
#  '/wiki/Talk:Orochi_Oniwabanshu',
#  '/wiki/Talk:Charlotte_Brownie',
#  '/wiki/Template_talk:Chapter_Box',
#  '/wiki/One_Piece_Wiki_talk:Guidebook/Manual_of_Style',
#  '/wiki/Special:Statistics',
#  '/wiki/Special:AllPages',
#  '/wiki/One_Piece_Wiki:Overview',
#  '/wiki/One_Piece_Wiki:Quick_Index',
#  '/wiki/Special:Categories',
#  'https://community.fandom.com/wiki/Help:Contents',
#  '/wiki/One_Piece_Wiki:FAQ',
#  '/wiki/One_Piece_Wiki:Copyrights',
#  '/wiki/Forum:Main_Page_Redesign',
#  'https://onepiece.fandom.com/main/section/Featured%20Articles',
#  'https://onepiece.fandom.com/main/section/One%20Piece%20Manga',
#  'https://onepiece.fandom.com/main/section/One%20Piece%20Anime',
#  'https://onepiece.fandom.com/main/section/Characters',
#  'https://onepiece.fandom.com/main/section/Universe',
#  'https://onepiece.fandom.com/main/section/Other%20Media',
#  'https://onepiece.fandom.com/main/section/Objects',
#  'https://jump.fandom.com/wiki/',
#  'https://onepiece.fandom.com/wiki/',
#  'https://hunterxhunter.fandom.com/wiki/',
#  'https://myheroacademia.fandom.com/wiki/',
#  'https://blackclover.fandom.com/wiki/',
#  'https://jujutsu-kaisen.fandom.com/wiki/',
#  'https://mission-yozakura-family.fandom.com/wiki/',
#  'https://undead-unluck.fandom.com/wiki/',
#  'https://mashle.fandom.com/wiki/',
#  'https://ayakashi-triangle.fandom.com/wiki/',
#  'https://me-and-roboco.fandom.com/wiki/',
#  'https://burn-the-witch.fandom.com/wiki/',
#  'https://high-school-family.fandom.com/wiki/',
#  'https://sakamoto-days.fandom.com/wiki/',
#  'https://the-elusive-samurai.fandom.com/wiki/',
#  'https://witch-watch.fandom.com/wiki/',
#  'https://blue-box.fandom.com/wiki/',
#  'https://pppppp.fandom.com/wiki/',
#  'https://ayashimon.fandom.com/wiki/',
#  'https://community.fandom.com/wiki/c:mamore-shugomaru',
#  'https://dorondororon.fandom.com/wiki/',
#  'https://akane-banashi.fandom.com/wiki/',
#  'https://earthchild.fandom.com/wiki/',
#  'https://dragonquest.fandom.com/wiki/Dragon_Quest:_Dai_no_Daib%C5%8Dken',
#  'https://dragonquest.fandom.com/wiki/Dragon_Quest:_Dai_no_Daib%C5%8Dken',
#  'https://onepiece.fandom.com/wiki/',
#  'https://onepiece.fandom.com/wiki/',
#  'https://shamanking.fandom.com/wiki/',
#  'https://shamanking.fandom.com/wiki/',
#  'https://ayakashi-triangle.fandom.com/wiki/',
#  'https://ayakashi-triangle.fandom.com/wiki/',
#  'https://blackclover.fandom.com/wiki/',
#  'https://blackclover.fandom.com/wiki/',
#  'https://bleach.fandom.com/wiki/',
#  'https://bleach.fandom.com/wiki/',
#  'https://chainsaw-man.fandom.com/wiki/',
#  'https://chainsaw-man.fandom.com/wiki/',
#  'https://dr-stone.fandom.com/wiki/',
#  'https://dr-stone.fandom.com/wiki/',
#  'https://jujutsu-kaisen.fandom.com/wiki/',
#  'https://jujutsu-kaisen.fandom.com/wiki/',
#  'https://kimetsu-no-yaiba.fandom.com/wiki/',
#  'https://kimetsu-no-yaiba.fandom.com/wiki/',
#  'https://myheroacademia.fandom.com/wiki/',
#  'https://myheroacademia.fandom.com/wiki/',
#  'https://slamdunk.fandom.com/wiki/',
#  'https://slamdunk.fandom.com/wiki/',
#  'https://act-age.fandom.com/wiki/',
#  'https://agravity-boys.fandom.com/wiki/',
#  'https://ansatsukyoshitsu.fandom.com/wiki/',
#  'https://bakuman.fandom.com/wiki/',
#  'https://bastard.fandom.com/wiki/',
#  'https://beastchildren.fandom.com/wiki/',
#  'https://beelzebub.fandom.com/wiki/',
#  'https://blackcat.fandom.com/wiki/',
#  'https://bleach.fandom.com/wiki/',
#  'https://bobobo.fandom.com/wiki/',
#  'https://bone-collection.fandom.com/wiki/',
#  'https://naruto.fandom.com/wiki/',
#  'https://bozebeats.fandom.com/wiki/',
#  'https://build-king.fandom.com/wiki/',
#  'https://busorenkin.fandom.com/wiki/',
#  'https://ame-no-furu.fandom.com/wiki/',
#  'https://captaintsubasa.fandom.com/wiki/',
#  'https://chainsaw-man.fandom.com/wiki/',
#  'https://cityhunter.fandom.com/wiki/',
#  'https://cyberblue.fandom.com/wiki/',
#  'https://dgrayman.fandom.com/wiki/',
#  'https://deathnote.fandom.com/wiki/',
#  'https://demonsplan.fandom.com/wiki/',
#  'https://dna2.fandom.com/wiki/',
#  'https://drslump.fandom.com/wiki/',
#  'https://dr-stone.fandom.com/wiki/',
#  'https://dragonball.fandom.com/wiki/',
#  'https://eyeshield21.fandom.com/wiki/',
#  'https://community.fandom.com/wiki/c:fulldrive',
#  'https://community.fandom.com/wiki/c:gakkyu-hotei',
#  'https://gintama.fandom.com/wiki/',
#  'https://guardian-of-the-witch.fandom.com/wiki/',
#  'https://hokuto.fandom.com/wiki/',
#  'https://haikyuu.fandom.com/wiki/',
#  'https://hatsukoilimited.fandom.com/wiki/',
#  'https://hardboiled-cop-and-dolphin.fandom.com/wiki/',
#  'https://hell-teacher-nube.fandom.com/wiki/',
#  'https://hikago.fandom.com/wiki/',
#  'https://hinomaruzumo.fandom.com/wiki/',
#  'https://houshinengi.fandom.com/wiki/',
#  'https://hungryjoker.fandom.com/wiki/',
#  'https://strawberry100.fandom.com/wiki/',
#  'https://ironknight.fandom.com/wiki/',
#  'https://ai-terushi.fandom.com/wiki/',
#  'https://jojo.fandom.com/wiki/',
#  'https://kagamigami.fandom.com/wiki/',
#  'https://kain.fandom.com/wiki/',
#  'https://kamioyui.fandom.com/wiki/',
#  'https://reborn.fandom.com/wiki/',
#  'https://kimetsu-no-yaiba.fandom.com/wiki/',
#  'https://kinnikuman.fandom.com/wiki/',
#  'https://kochikame.fandom.com/wiki/',
#  'https://kurogane.fandom.com/wiki/',
#  'https://kurokonobasuke.fandom.com/wiki/',
#  'https://nogamineuro.fandom.com/wiki/',
#  ...]

# %%
tag_list_link = [t[6:] for t in tag_list if (t) and (t.startswith('/wiki/'))]
tag_list_link
# Out:
# ['Monkey_D._Luffy',
#  'Straw_Hat_Pirates',
#  'List_of_Canon_Characters',
#  'List_of_Non-Canon_Characters',
#  'Pirates',
#  'Marines',
#  'Category:Races_and_Tribes',
#  'Category:Antagonists',
#  'Category:Occupations',
#  'Category:Races_and_Tribes',
#  'Category:Technology',
#  'Animal_Species',
#  'Grand_Line',
#  'Category:Islands',
#  'East_Blue',
#  'New_World',
#  'Marines',
#  'Pirates',
#  'Seven_Warlords_of_the_Sea',
#  'Four_Emperors',
#  'World_Government',
#  'Revolutionary_Army',
#  'Devil_Fruit',
#  'Gomu_Gomu_no_Mi',
#  'Paramecia',
#  'Zoan',
#  'Logia',
#  'Artificial_Devil_Fruit',
#  'Devil_Fruit#Natural_Devil_Fruits',
#  'SMILE',
#  'Category:Non-Canon_Devil_Fruits',
#  'One_Piece_Wiki:Guidebook',
#  'One_Piece_Wiki:Guidebook/Referencing_Information',
#  'User_blog:Leviathan_89/What_you_have_to_know_about_signatures',
#  'One_Piece_Wiki:FAQ',
#  'One_Piece_Wiki:Wiki_Crews',
#  'Category:Chapter_Stubs',
#  'Category:Episode_Stubs',
#  'Chapters_and_Volumes/Volume_1-10',
#  'Chapters_and_Volumes/Volume_11-20',
#  'Chapters_and_Volumes/Volume_21-30',
#  'Chapters_and_Volumes/Volume_31-40',
#  'Chapters_and_Volumes/Volume_41-50',
#  'Chapters_and_Volumes/Volume_51-60',
#  'Chapters_and_Volumes/Volume_61-70',
#  'Chapters_and_Volumes/Volume_71-80',
#  'Chapters_and_Volumes/Volume_81-90',
#  'Chapters_and_Volumes/Volume_91-100',
#  'Chapters_and_Volumes/Volume_101-110',
#  'Chapters_and_Volumes/Special',
#  'SBS_Volume_4',
#  'SBS_Volume_5',
#  'SBS_Volume_6',
#  'SBS_Volume_7',
#  'SBS_Volume_8',
#  'SBS_Volume_9',
#  'SBS_Volume_10',
#  'SBS_Volume_11',
#  'SBS_Volume_12',
#  'SBS_Volume_13',
#  'SBS_Volume_14',
#  'SBS_Volume_15',
#  'SBS_Volume_16',
#  'SBS_Volume_17',
#  'SBS_Volume_18',
#  'SBS_Volume_19',
#  'SBS_Volume_20',
#  'SBS_Volume_21',
#  'SBS_Volume_22',
#  'SBS_Volume_23',
#  'SBS_Volume_24',
#  'SBS_Volume_25',
#  'SBS_Volume_26',
#  'SBS_Volume_27',
#  'SBS_Volume_28',
#  'SBS_Volume_29',
#  'SBS_Volume_30',
#  'SBS_Volume_31',
#  'SBS_Volume_32',
#  'SBS_Volume_33',
#  'SBS_Volume_34',
#  'SBS_Volume_35',
#  'SBS_Volume_36',
#  'SBS_Volume_37',
#  'SBS_Volume_38',
#  'SBS_Volume_39',
#  'SBS_Volume_40',
#  'SBS_Volume_41',
#  'SBS_Volume_42',
#  'SBS_Volume_43',
#  'SBS_Volume_44',
#  'SBS_Volume_45',
#  'SBS_Volume_46',
#  'SBS_Volume_47',
#  'SBS_Volume_48',
#  'SBS_Volume_49',
#  'SBS_Volume_50',
#  'SBS_Volume_51',
#  'SBS_Volume_52',
#  'SBS_Volume_53',
#  'SBS_Volume_54',
#  'SBS_Volume_55',
#  'SBS_Volume_56',
#  'SBS_Volume_57',
#  'SBS_Volume_58',
#  'SBS_Volume_59',
#  'SBS_Volume_60',
#  'SBS_Volume_61',
#  'SBS_Volume_62',
#  'SBS_Volume_63',
#  'SBS_Volume_64',
#  'SBS_Volume_65',
#  'SBS_Volume_66',
#  'SBS_Volume_67',
#  'SBS_Volume_68',
#  'SBS_Volume_69',
#  'SBS_Volume_70',
#  'SBS_Volume_71',
#  'SBS_Volume_72',
#  'SBS_Volume_73',
#  'SBS_Volume_74',
#  'SBS_Volume_75',
#  'SBS_Volume_76',
#  'SBS_Volume_77',
#  'SBS_Volume_78',
#  'SBS_Volume_79',
#  'SBS_Volume_80',
#  'SBS_Volume_81',
#  'SBS_Volume_82',
#  'SBS_Volume_83',
#  'SBS_Volume_84',
#  'SBS_Volume_85',
#  'SBS_Volume_86',
#  'SBS_Volume_87',
#  'SBS_Volume_88',
#  'SBS_Volume_89',
#  'SBS_Volume_90',
#  'SBS_Volume_91',
#  'SBS_Volume_92',
#  'SBS_Volume_93',
#  'SBS_Volume_94',
#  'SBS_Volume_95',
#  'SBS_Volume_96',
#  'SBS_Volume_97',
#  'SBS_Volume_98',
#  'SBS_Volume_99',
#  'SBS_Volume_100',
#  'SBS_Volume_101',
#  'Author%27s_Notes#Volume_1',
#  'Author%27s_Notes#Volume_2',
#  'Author%27s_Notes#Volume_3',
#  'Author%27s_Notes#Volume_4',
#  'Author%27s_Notes#Volume_5',
#  'Author%27s_Notes#Volume_6',
#  'Author%27s_Notes#Volume_7',
#  'Author%27s_Notes#Volume_8',
#  'Author%27s_Notes#Volume_9',
#  'Author%27s_Notes#Volume_10',
#  'Author%27s_Notes#Volume_11',
#  'Author%27s_Notes#Volume_12',
#  'Author%27s_Notes#Volume_13',
#  'Author%27s_Notes#Volume_14',
#  'Author%27s_Notes#Volume_15',
#  'Author%27s_Notes#Volume_16',
#  'Author%27s_Notes#Volume_17',
#  'Author%27s_Notes#Volume_18',
#  'Author%27s_Notes#Volume_19',
#  'Author%27s_Notes#Volume_20',
#  'Author%27s_Notes#Volume_21',
#  'Author%27s_Notes#Volume_22',
#  'Author%27s_Notes#Volume_23',
#  'Author%27s_Notes#Volume_24',
#  'Author%27s_Notes#Volume_25',
#  'Author%27s_Notes#Volume_26',
#  'Author%27s_Notes#Volume_27',
#  'Author%27s_Notes#Volume_28',
#  'Author%27s_Notes#Volume_29',
#  'Author%27s_Notes#Volume_30',
#  'Author%27s_Notes#Volume_31',
#  'Author%27s_Notes#Volume_32',
#  'Author%27s_Notes#Volume_33',
#  'Author%27s_Notes#Volume_34',
#  'Author%27s_Notes#Volume_35',
#  'Author%27s_Notes#Volume_36',
#  'Author%27s_Notes#Volume_37',
#  'Author%27s_Notes#Volume_38',
#  'Author%27s_Notes#Volume_39',
#  'Author%27s_Notes#Volume_40',
#  'Author%27s_Notes#Volume_41',
#  'Author%27s_Notes#Volume_42',
#  'Author%27s_Notes#Volume_43',
#  'Author%27s_Notes#Volume_44',
#  'Author%27s_Notes#Volume_45',
#  'Author%27s_Notes#Volume_46',
#  'Author%27s_Notes#Volume_47',
#  'Author%27s_Notes#Volume_48',
#  'Author%27s_Notes#Volume_49',
#  'Author%27s_Notes#Volume_50',
#  'Author%27s_Notes#Volume_51',
#  'Author%27s_Notes#Volume_52',
#  'Author%27s_Notes#Volume_53',
#  'Author%27s_Notes#Volume_54',
#  'Author%27s_Notes#Volume_55',
#  'Author%27s_Notes#Volume_56',
#  'Author%27s_Notes#Volume_57',
#  'Author%27s_Notes#Volume_58',
#  'Author%27s_Notes#Volume_59',
#  'Author%27s_Notes#Volume_60',
#  'Author%27s_Notes#Volume_61',
#  'Author%27s_Notes#Volume_62',
#  'Author%27s_Notes#Volume_63',
#  'Author%27s_Notes#Volume_64',
#  'Author%27s_Notes#Volume_65',
#  'Author%27s_Notes#Volume_66',
#  'Author%27s_Notes#Volume_67',
#  'Author%27s_Notes#Volume_68',
#  'Author%27s_Notes#Volume_69',
#  'Author%27s_Notes#Volume_70',
#  'Author%27s_Notes#Volume_71',
#  'Author%27s_Notes#Volume_72',
#  'Author%27s_Notes#Volume_73',
#  'Author%27s_Notes#Volume_74',
#  'Author%27s_Notes#Volume_75',
#  'Author%27s_Notes#Volume_76',
#  'Author%27s_Notes#Volume_77',
#  'Author%27s_Notes#Volume_78',
#  'Author%27s_Notes#Volume_79',
#  'Author%27s_Notes#Volume_80',
#  'Author%27s_Notes#Volume_81',
#  'Author%27s_Notes#Volume_82',
#  'Author%27s_Notes#Volume_83',
#  'Author%27s_Notes#Volume_84',
#  'Author%27s_Notes#Volume_85',
#  'Author%27s_Notes#Volume_86',
#  'Author%27s_Notes#Volume_87',
#  'Author%27s_Notes#Volume_88',
#  'Author%27s_Notes#Volume_89',
#  'Author%27s_Notes#Volume_90',
#  'Author%27s_Notes#Volume_91',
#  'Author%27s_Notes#Volume_92',
#  'Author%27s_Notes#Volume_93',
#  'Author%27s_Notes#Volume_94',
#  'Author%27s_Notes#Volume_95',
#  'Author%27s_Notes#Volume_96',
#  'Author%27s_Notes#Volume_97',
#  'Author%27s_Notes#Volume_98',
#  'Author%27s_Notes#Volume_99',
#  'Author%27s_Notes#Volume_100',
#  'Author%27s_Notes#Volume_101',
#  'Author%27s_Notes#Wanted.21',
#  'Author%27s_Notes#STRONG_WORLD',
#  'Author%27s_Notes#One_Piece_Rainbow.21_Official_Animation_Guide_Book',
#  'Author%27s_Notes#One_Piece_White.21',
#  'Author%27s_Notes#Volume_1000',
#  'Author%27s_Notes#One_Piece_500_Quiz_Book',
#  'Author%27s_Notes#Volume_777',
#  'One_Piece_Red:_Grand_Characters',
#  'One_Piece_Blue:_Grand_Data_File',
#  'One_Piece_Yellow:_Grand_Elements',
#  'One_Piece_Green:_Secret_Pieces',
#  'One_Piece_Blue_Deep:_Characters_World',
#  'Vivre_Card_-_One_Piece_Visual_Dictionary',
#  'Buggy%27s_Crew:_After_the_Battle!',
#  'Diary_of_Coby-Meppo',
#  'Jango%27s_Dance_Paradise',
#  'Hatchan%27s_Sea-Floor_Stroll',
#  'Wapol%27s_Omnivorous_Hurrah',
#  'Ace%27s_Great_Blackbeard_Search',
#  'Gedatsu%27s_Accidental_Blue-Sea_Life',
#  'Miss_Goldenweek%27s_%22Operation:_Meet_Baroque_Works%22',
#  'Enel%27s_Great_Space_Operations',
#  'CP9%27s_Independent_Report',
#  'Straw_Hat%27s_Separation_Serial',
#  'From_the_Decks_of_the_World',
#  'Caribou%27s_Kehihihihi_in_the_New_World',
#  'Solo_Journey_of_Jinbe,_Knight_of_the_Sea',
#  'From_the_Decks_of_the_World:_The_500,000,000_Man_Arc',
#  'The_Stories_of_the_Self-Proclaimed_Straw_Hat_Grand_Fleet',
#  '%22Gang%22_Bege%27s_Oh_My_Family',
#  'Episode_Guide/East_Blue_Saga',
#  'Episode_Guide/Alabasta_Saga',
#  'Episode_Guide/Sky_Island_Saga',
#  'Episode_Guide/Water_7_Saga',
#  'Episode_Guide/Thriller_Bark_Saga',
#  'Episode_Guide/Summit_War_Saga',
#  'Episode_Guide/Fishman_Island_Saga',
#  'Episode_Guide/Dressrosa_Saga',
#  'Episode_Guide/Four_Emperors_Saga',
#  'One_Piece:_The_Movie',
#  'Clockwork_Island_Adventure',
#  'Chopper%27s_Kingdom_on_the_Island_of_Strange_Animals',
#  'Dead_End_Adventure',
#  'The_Cursed_Holy_Sword',
#  'Baron_Omatsuri_and_the_Secret_Island',
#  'The_Giant_Mechanical_Soldier_of_Karakuri_Castle',
#  'Episode_of_Alabasta:_The_Desert_Princess_and_the_Pirates',
#  'Episode_of_Chopper_Plus:_Bloom_in_Winter,_Miracle_Sakura',
#  'One_Piece_Film:_Strong_World',
#  'One_Piece_3D:_Straw_Hat_Chase',
#  'One_Piece_Film:_Z',
#  'One_Piece_Film:_Gold',
#  'One_Piece:_Stampede',
#  'One_Piece_Film:_Red',
#  'Warship_Island_Arc',
#  'Post-Alabasta_Arc',
#  'Goat_Island_Arc',
#  'Ruluka_Island_Arc',
#  'G-8_Arc',
#  'Ocean%27s_Dream_Arc',
#  'Foxy%27s_Return_Arc',
#  'Ice_Hunter_Arc',
#  'Spa_Island_Arc',
#  'Little_East_Blue_Arc',
#  'Z%27s_Ambition_Arc',
#  'Caesar_Retrieval_Arc',
#  'Silver_Mine_Arc',
#  'Marine_Rookie_Arc',
#  'Cidre_Guild_Arc',
#  'One_Piece_Soundtracks',
#  'Movie_2_OST',
#  'Movie_3_OST',
#  'Movie_4_OST',
#  'Movie_6_OST',
#  'Movie_7_OST',
#  'Movie_8_OST',
#  'Movie_10_OST',
#  'One_Piece_Film_Z_OST',
#  'Episode_Special_1',
#  'Episode_Special_2',
#  'Episode_Special_3',
#  'Episode_Special_4',
#  'Episode_of_Nami',
#  'Episode_of_Luffy',
#  'Episode_of_Merry',
#  '3D2Y',
#  'Adventure_of_Nebulandia',
#  'Episode_of_Sabo',
#  'Glorious_Island',
#  'Heart_of_Gold',
#  'Episode_of_East_Blue',
#  'Episode_of_Sky_Island',
#  'We_Are!',
#  'Believe',
#  'Hikari_e',
#  'BON_VOYAGE!',
#  'Kokoro_no_Chizu',
#  'Brand_New_World',
#  'Crazy_Rainbow',
#  'Jungle_P',
#  'Share_the_World',
#  'Kaze_wo_Sagashite',
#  'One_day',
#  'Fight_Together',
#  'We_Go!',
#  'Hands_Up!',
#  'Wake_up!',
#  'Hard_Knock_Days',
#  'We_Can!',
#  'Hope',
#  'Super_Powers',
#  'OVER_THE_TOP',
#  'DREAMIN%27_ON',
#  'PAINT',
#  'Monkey_D._Luffy',
#  'Roronoa_Zoro',
#  'Nami',
#  'Usopp',
#  'Sanji',
#  'Tony_Tony_Chopper',
#  'Nico_Robin',
#  'Franky',
#  'Brook',
#  'Jinbe',
#  'Shanks',
#  'Koby',
#  'Gaimon',
#  'Kaya',
#  'Johnny',
#  'Yosaku',
#  'Zeff',
#  'Nojiko',
#  'Bell-m%C3%A8re',
#  'Higuma',
#  'Alvida',
#  'Morgan',
#  'Helmeppo',
#  'Buggy',
#  'Kuro',
#  'Krieg',
#  'Gin',
#  'Arlong',
#  'Nefertari_Vivi',
#  'Laboon',
#  'Karoo',
#  'Dorry',
#  'Brogy',
#  'Dalton',
#  'Kureha',
#  'Portgas_D._Ace',
#  'Igaram',
#  'Kohza',
#  'Nefertari_Cobra',
#  'Smoker',
#  'Wapol',
#  'Mikita',
#  'Gem',
#  'Marianne',
#  'Galdino',
#  'Bentham',
#  'Zala',
#  'Daz_Bonez',
#  'Crocodile',
#  'Mont_Blanc_Cricket',
#  'Conis',
#  'Pagaya',
#  'Wyper',
#  'Gan_Fall',
#  'Aisa',
#  'Montblanc_Noland',
#  'Kalgara',
#  'Bellamy',
#  'Enel',
#  'Satori',
#  'Shura',
#  'Gedatsu',
#  'Ohm',
#  'Iceburg',
#  'Paulie',
#  'Kokoro',
#  'Galley-La_Company',
#  'Franky_Family',
#  'Rob_Lucci',
#  'Kaku',
#  'Jabra',
#  'Blueno',
#  'Kalifa',
#  'Fukurou',
#  'Kumadori',
#  'Spandam',
#  'Kuzan',
#  'Foxy',
#  'Charlotte_Lola',
#  'Gekko_Moriah',
#  'Hogback',
#  'Absalom',
#  'Perona',
#  'Oars',
#  'Ryuma',
#  'Bartholomew_Kuma',
#  'Keimi',
#  'Pappug',
#  'Hatchan',
#  'Silvers_Rayleigh',
#  'Worst_Generation',
#  'Boa_Hancock',
#  'Emporio_Ivankov',
#  'Edward_Newgate',
#  'Marco',
#  'Duval',
#  'Charlos',
#  'Marshall_D._Teach',
#  'Magellan',
#  'Hannyabal',
#  'Sakazuki',
#  'Kuzan',
#  'Borsalino',
#  'Sentomaru',
#  'Dracule_Mihawk',
#  'Donquixote_Doflamingo',
#  'Momonga',
#  'Shirahoshi',
#  'Neptune',
#  'Surume',
#  'Shyarly',
#  'Trafalgar_D._Water_Law',
#  'Kin%27emon',
#  'Kozuki_Momonosuke',
#  'Kurozumi_Kanjuro',
#  'Chadros_Higelyges',
#  'Bartolomeo',
#  'Cavendish',
#  'Rebecca',
#  'Kyros',
#  'Riku_Doldo_III',
#  'Sabo',
#  'Caribou',
#  'Hody_Jones',
#  'Vander_Decken_IX',
#  'Hyouzou',
#  'Caesar_Clown',
#  'Monet',
#  'Vergo',
#  'Trebol',
#  'Diamante',
#  'Pica',
#  'Senor_Pink',
#  'Buffalo',
#  'Baby_5',
#  'Issho',
#  'Raizo',
#  'Carrot',
#  'Pedro',
#  'Wanda',
#  'Inuarashi',
#  'Nekomamushi',
#  'Pekoms',
#  'Zunesha',
#  'Capone_Bege',
#  'Kaidou',
#  'Jack',
#  'Charlotte_Linlin',
#  'Vinsmoke_Judge',
#  'Charlotte_Katakuri',
#  'Charlotte_Pudding',
#  'Charlotte_Cracker',
#  'Charlotte_Smoothie',
#  'Charlotte_Perospero',
#  'Kozuki_Oden',
#  'Kozuki_Hiyori',
#  'Kikunojo',
#  'Denjiro',
#  'Ashura_Doji',
#  'Kawamatsu',
#  'Shinobu',
#  'Hyogoro',
#  'Shimotsuki_Yasuie',
#  'Yamato',
#  'King',
#  'Queen',
#  'Who%27s-Who',
#  'Black_Maria',
#  'Sasaki',
#  'Page_One',
#  'Ulti',
#  'Scratchmen_Apoo',
#  'Numbers',
#  'One_Piece:_Stampede',
#  'One_Piece_Volume_10089',
#  'Cidre_Guild_Arc',
#  'Monkey_D._Luffy',
#  'Trafalgar_D._Water_Law',
#  'Sabo',
#  'Boa_Hancock',
#  'Buggy',
#  'Smoker',
#  'Rob_Lucci',
#  'Crocodile',
#  'Douglas_Bullet',
#  'Buena_Festa',
#  'Donald_Moderate',
#  'Ann',
#  'Cidre',
#  'Guarana',
#  'Ginger',
#  'Gol_D._Roger',
#  'Pirates_Festival',
#  'Delta_Island',
#  'Gasha_Gasha_no_Mi',
#  'Bijo_Bijo_no_Mi',
#  'Cidre_Guild',
#  'One_Piece_Wiki:Guidebook',
#  'One_Piece_Wiki:FAQ',
#  'One_Piece_Wiki:Guidebook/User_Rights',
#  'Special:Forum',
#  'Blog:Recent_posts',
#  'One_Piece_(Manga)',
#  'One_Piece_(Anime)',
#  'Eiichiro_Oda',
#  'One_Piece_Wiki:Spoiler_Rules',
#  'Artificial_Devil_Fruit',
#  'Devil_Fruit',
#  'Vegapunk',
#  'SMILE',
#  'Caesar_Clown',
#  'Artificial_Devil_Fruit',
#  'Marshall_D._Teach',
#  'Template:Current_Events/Manga',
#  'Chapter_1044',
#  'Monkey_D._Luffy',
#  'Five_Elders',
#  'Nika',
#  'Gomu_Gomu_no_Mi',
#  'Kozuki_Hiyori',
#  'Kurozumi_Orochi',
#  'Kazenbo',
#  'Kaidou',
#  'Gomu_Gomu_no_Mi/Gear_Fifth_Techniques',
#  'Chapter_1044',
#  'Template:Current_Events/Anime',
#  'Episode_1013',
#  'Episode_1013',
#  'Episode_1014',
#  'User:Gomuking',
#  'User:Gomuking',
#  'User_blog:Gomuking/how_strong_do_you_think_game_luffy_is',
#  'User_blog:Gomuking/how_strong_do_you_think_game_luffy_is',
#  'User:OdaFan',
#  'User:OdaFan',
#  'User_blog:OdaFan/Ton_Ton_fruit_is_the_most_dangerous_fruit',
#  'User_blog:OdaFan/Ton_Ton_fruit_is_the_most_dangerous_fruit',
#  'User:JackSpicer305',
#  'User:JackSpicer305',
#  'User_blog:JackSpicer305/The_Mishandling_of_the_Nine_Red_Scabbards',
#  'User_blog:JackSpicer305/The_Mishandling_of_the_Nine_Red_Scabbards',
#  'User:Shonennarutoz',
#  'User:Shonennarutoz',
#  'User_blog:Shonennarutoz/Naruto_or_One_piece',
#  'User_blog:Shonennarutoz/Naruto_or_One_piece',
#  'User:Gomuking',
#  'User:Gomuking',
#  'User_blog:Gomuking/who%27s_techniqes_are_better',
#  'User_blog:Gomuking/who%27s_techniqes_are_better',
#  'User:Gomuking',
#  'User:Gomuking',
#  'User_blog:Gomuking/who%27s_fire_is_better',
#  'User_blog:Gomuking/who%27s_fire_is_better',
#  'Blog:Recent_Blog_Posts',
#  'FUNimation',
#  'Saru',
#  'Real-Life_Timeline',
#  'Aim!_The_King_of_Belly',
#  'Real-Life_Timeline',
#  'Episode_187',
#  'Episode_188',
#  'Real-Life_Timeline',
#  'Chapter_360',
#  'Real-Life_Timeline',
#  'Episode_444',
#  'Real-Life_Timeline',
#  'Episode_967',
#  'Episode_Guide',
#  'One_Piece_(Manga)',
#  'Chapters_and_Volumes',
#  'One_Piece_Movies',
#  'List_of_Locations',
#  'World_Timeline',
#  'Category:Society_and_Culture',
#  'List_of_Canon_Characters',
#  'Animal_Species',
#  'One_Piece_Merchandise',
#  'One_Piece_Voice_Actors',
#  'Category:One_Piece_International',
#  'Template:Releases',
#  'Template:Releases',
#  'Volume_101',
#  'Home_Video_Releases/Seasons_16-20#Season_20',
#  'Volume_99',
#  'FUNimation/Seasons_10-12#Season_11',
#  'Montblanc_Noland',
#  'Pumpkins',
#  'Jaya',
#  'Arabasta',
#  'Arabasta',
#  'Cavendish',
#  'Mythbusters',
#  'MediaWiki:Uploadtext',
#  'One_Piece_Wiki:Research_Crew',
#  'Forum:Revamping_Featured_Articles',
#  'One_Piece_Wiki:Separate_Volume_Pages_Project',
#  'One_Piece_Wiki:Categorization_Fixing_Project',
#  'Forum:Changing_the_Purpose_of_this_Forum',
#  'User:Adv193',
#  'Forum:More_Category_Issues',
#  'Special:Contributions/Tokina8937',
#  'Forum:Videos,_Timestamps_and_MP3s',
#  'User:Rgilbert27',
#  'Forum:Tabs_changes',
#  'User:Leviathan_89',
#  'Forum:Trivia_on_Chapter_and_Episode_pages',
#  'User:Rhavkin',
#  'Forum:Conjectural_Portrait_Guidelines',
#  'User:Nightmare_Pirates',
#  'Forum:Weapon_Usage_Categories',
#  'Forum:Removing_Movies_and_Specials_From_Character_Histories',
#  'Forum:Allies_Sections_on_Group_Galleries',
#  'Talk:Gomu_Gomu_no_Mi',
#  'User:Sarutobii2',
#  'Category_talk:Volume_Chapter_Images',
#  'User:Rgilbert27',
#  'Category_talk:Infobox_Templates',
#  'User:Montblanc_Noland',
#  'File_talk:Narikabura_Arrow.png',
#  'User:Dragonus_Nesha',
#  'Talk:Marshall_D._Teach',
#  'User:Marco_1907',
#  'Category_talk:Characters_by_Position',
#  'User:Rgilbert27',
#  'Category_talk:Military_Forces',
#  'User:Montblanc_Noland',
#  'Talk:Zombie',
#  'User:Rgilbert27',
#  'Talk:Funimation/Episode_List_and_DVD_Releases',
#  'User:Kaido_King_of_the_Beasts',
#  'Talk:Arabasta_Kingdom',
#  'Special:Contributions/Ranafor',
#  'Talk:Foods',
#  'User:Rgilbert27',
#  'Talk:Maki_Maki_no_Mi',
#  'User:Dragonus_Nesha',
#  'Template_talk:Straw_Hat_Pirates_Gallery',
#  'User:Dragonus_Nesha',
#  'Category_talk:Conjectural_Portraits',
#  'User:Rgilbert27',
#  'Talk:One_Piece_1000_Logs',
#  'User:Rgilbert27',
#  'Talk:Onigashima',
#  'User:Rgilbert27',
#  'One_Piece_Wiki_talk:Image_Crew',
#  'User:Kaido_King_of_the_Beasts',
#  'Talk:Swordsman',
#  'User:Rgilbert27',
#  'File_talk:Monkey_D._Luffy_Portrait.png',
#  'User:Kaido_King_of_the_Beasts',
#  'Talk:One_Piece_10th_Treasures',
#  'User:Leviathan_89',
#  'Talk:List_of_volumes_released_in_Latin_America',
#  'User:Rgilbert27',
#  'Talk:Page_One',
#  'User:Dragonus_Nesha',
#  'Template_talk:Char_Box',
#  'User:Leviathan_89',
#  'Talk:Brontosaurus',
#  'User:Dragonus_Nesha',
#  'Talk:Bustercall_Project',
#  'User:Awaikage',
#  'Template_talk:ChapterPages',
#  'User:Leviathan_89',
#  'Talk:One_Piece_Rap',
#  'User:Kaido_King_of_the_Beasts',
#  'Talk:Amber_Lead',
#  'User:Rhavkin',
#  'Talk:Chapter_977',
#  'One_Piece_Wiki_talk:Guidebook/Spoiler_Rules',
#  'Talk:Poneglyph',
#  'Talk:Orochi_Oniwabanshu',
#  'Talk:Charlotte_Brownie',
#  'Template_talk:Chapter_Box',
#  'One_Piece_Wiki_talk:Guidebook/Manual_of_Style',
#  'Special:Statistics',
#  'Special:AllPages',
#  'One_Piece_Wiki:Overview',
#  'One_Piece_Wiki:Quick_Index',
#  'Special:Categories',
#  'One_Piece_Wiki:FAQ',
#  'One_Piece_Wiki:Copyrights',
#  'Forum:Main_Page_Redesign']

# %% [markdown]
# ### Create a filter for unwanted types of articles

# %%
word_filter = '(%s)' % '|'.join([
    'Category:',
    'One_Piece_Wiki:',
    'User:',
    'User_blog:',
    'Help:',
    'action=',
    'Special:',
    'SBS_Volume',
    'Chapters_and_Volumes', 
    'Author%27s_Notes',
    'Episode_Guide',
    'Movie_',
    'Episode_Special',
    'Forum:',
    'File_',
    'Category_',
    'Talk:',

    
])
tag_list_final = [t for t in tag_list_link if not re.search(word_filter, t)]
tag_list_final
# Out:
# ['Monkey_D._Luffy',
#  'Straw_Hat_Pirates',
#  'List_of_Canon_Characters',
#  'List_of_Non-Canon_Characters',
#  'Pirates',
#  'Marines',
#  'Animal_Species',
#  'Grand_Line',
#  'East_Blue',
#  'New_World',
#  'Marines',
#  'Pirates',
#  'Seven_Warlords_of_the_Sea',
#  'Four_Emperors',
#  'World_Government',
#  'Revolutionary_Army',
#  'Devil_Fruit',
#  'Gomu_Gomu_no_Mi',
#  'Paramecia',
#  'Zoan',
#  'Logia',
#  'Artificial_Devil_Fruit',
#  'Devil_Fruit#Natural_Devil_Fruits',
#  'SMILE',
#  'One_Piece_Red:_Grand_Characters',
#  'One_Piece_Blue:_Grand_Data_File',
#  'One_Piece_Yellow:_Grand_Elements',
#  'One_Piece_Green:_Secret_Pieces',
#  'One_Piece_Blue_Deep:_Characters_World',
#  'Vivre_Card_-_One_Piece_Visual_Dictionary',
#  'Buggy%27s_Crew:_After_the_Battle!',
#  'Diary_of_Coby-Meppo',
#  'Jango%27s_Dance_Paradise',
#  'Hatchan%27s_Sea-Floor_Stroll',
#  'Wapol%27s_Omnivorous_Hurrah',
#  'Ace%27s_Great_Blackbeard_Search',
#  'Gedatsu%27s_Accidental_Blue-Sea_Life',
#  'Miss_Goldenweek%27s_%22Operation:_Meet_Baroque_Works%22',
#  'Enel%27s_Great_Space_Operations',
#  'CP9%27s_Independent_Report',
#  'Straw_Hat%27s_Separation_Serial',
#  'From_the_Decks_of_the_World',
#  'Caribou%27s_Kehihihihi_in_the_New_World',
#  'Solo_Journey_of_Jinbe,_Knight_of_the_Sea',
#  'From_the_Decks_of_the_World:_The_500,000,000_Man_Arc',
#  'The_Stories_of_the_Self-Proclaimed_Straw_Hat_Grand_Fleet',
#  '%22Gang%22_Bege%27s_Oh_My_Family',
#  'One_Piece:_The_Movie',
#  'Clockwork_Island_Adventure',
#  'Chopper%27s_Kingdom_on_the_Island_of_Strange_Animals',
#  'Dead_End_Adventure',
#  'The_Cursed_Holy_Sword',
#  'Baron_Omatsuri_and_the_Secret_Island',
#  'The_Giant_Mechanical_Soldier_of_Karakuri_Castle',
#  'Episode_of_Alabasta:_The_Desert_Princess_and_the_Pirates',
#  'Episode_of_Chopper_Plus:_Bloom_in_Winter,_Miracle_Sakura',
#  'One_Piece_Film:_Strong_World',
#  'One_Piece_3D:_Straw_Hat_Chase',
#  'One_Piece_Film:_Z',
#  'One_Piece_Film:_Gold',
#  'One_Piece:_Stampede',
#  'One_Piece_Film:_Red',
#  'Warship_Island_Arc',
#  'Post-Alabasta_Arc',
#  'Goat_Island_Arc',
#  'Ruluka_Island_Arc',
#  'G-8_Arc',
#  'Ocean%27s_Dream_Arc',
#  'Foxy%27s_Return_Arc',
#  'Ice_Hunter_Arc',
#  'Spa_Island_Arc',
#  'Little_East_Blue_Arc',
#  'Z%27s_Ambition_Arc',
#  'Caesar_Retrieval_Arc',
#  'Silver_Mine_Arc',
#  'Marine_Rookie_Arc',
#  'Cidre_Guild_Arc',
#  'One_Piece_Soundtracks',
#  'One_Piece_Film_Z_OST',
#  'Episode_of_Nami',
#  'Episode_of_Luffy',
#  'Episode_of_Merry',
#  '3D2Y',
#  'Adventure_of_Nebulandia',
#  'Episode_of_Sabo',
#  'Glorious_Island',
#  'Heart_of_Gold',
#  'Episode_of_East_Blue',
#  'Episode_of_Sky_Island',
#  'We_Are!',
#  'Believe',
#  'Hikari_e',
#  'BON_VOYAGE!',
#  'Kokoro_no_Chizu',
#  'Brand_New_World',
#  'Crazy_Rainbow',
#  'Jungle_P',
#  'Share_the_World',
#  'Kaze_wo_Sagashite',
#  'One_day',
#  'Fight_Together',
#  'We_Go!',
#  'Hands_Up!',
#  'Wake_up!',
#  'Hard_Knock_Days',
#  'We_Can!',
#  'Hope',
#  'Super_Powers',
#  'OVER_THE_TOP',
#  'DREAMIN%27_ON',
#  'PAINT',
#  'Monkey_D._Luffy',
#  'Roronoa_Zoro',
#  'Nami',
#  'Usopp',
#  'Sanji',
#  'Tony_Tony_Chopper',
#  'Nico_Robin',
#  'Franky',
#  'Brook',
#  'Jinbe',
#  'Shanks',
#  'Koby',
#  'Gaimon',
#  'Kaya',
#  'Johnny',
#  'Yosaku',
#  'Zeff',
#  'Nojiko',
#  'Bell-m%C3%A8re',
#  'Higuma',
#  'Alvida',
#  'Morgan',
#  'Helmeppo',
#  'Buggy',
#  'Kuro',
#  'Krieg',
#  'Gin',
#  'Arlong',
#  'Nefertari_Vivi',
#  'Laboon',
#  'Karoo',
#  'Dorry',
#  'Brogy',
#  'Dalton',
#  'Kureha',
#  'Portgas_D._Ace',
#  'Igaram',
#  'Kohza',
#  'Nefertari_Cobra',
#  'Smoker',
#  'Wapol',
#  'Mikita',
#  'Gem',
#  'Marianne',
#  'Galdino',
#  'Bentham',
#  'Zala',
#  'Daz_Bonez',
#  'Crocodile',
#  'Mont_Blanc_Cricket',
#  'Conis',
#  'Pagaya',
#  'Wyper',
#  'Gan_Fall',
#  'Aisa',
#  'Montblanc_Noland',
#  'Kalgara',
#  'Bellamy',
#  'Enel',
#  'Satori',
#  'Shura',
#  'Gedatsu',
#  'Ohm',
#  'Iceburg',
#  'Paulie',
#  'Kokoro',
#  'Galley-La_Company',
#  'Franky_Family',
#  'Rob_Lucci',
#  'Kaku',
#  'Jabra',
#  'Blueno',
#  'Kalifa',
#  'Fukurou',
#  'Kumadori',
#  'Spandam',
#  'Kuzan',
#  'Foxy',
#  'Charlotte_Lola',
#  'Gekko_Moriah',
#  'Hogback',
#  'Absalom',
#  'Perona',
#  'Oars',
#  'Ryuma',
#  'Bartholomew_Kuma',
#  'Keimi',
#  'Pappug',
#  'Hatchan',
#  'Silvers_Rayleigh',
#  'Worst_Generation',
#  'Boa_Hancock',
#  'Emporio_Ivankov',
#  'Edward_Newgate',
#  'Marco',
#  'Duval',
#  'Charlos',
#  'Marshall_D._Teach',
#  'Magellan',
#  'Hannyabal',
#  'Sakazuki',
#  'Kuzan',
#  'Borsalino',
#  'Sentomaru',
#  'Dracule_Mihawk',
#  'Donquixote_Doflamingo',
#  'Momonga',
#  'Shirahoshi',
#  'Neptune',
#  'Surume',
#  'Shyarly',
#  'Trafalgar_D._Water_Law',
#  'Kin%27emon',
#  'Kozuki_Momonosuke',
#  'Kurozumi_Kanjuro',
#  'Chadros_Higelyges',
#  'Bartolomeo',
#  'Cavendish',
#  'Rebecca',
#  'Kyros',
#  'Riku_Doldo_III',
#  'Sabo',
#  'Caribou',
#  'Hody_Jones',
#  'Vander_Decken_IX',
#  'Hyouzou',
#  'Caesar_Clown',
#  'Monet',
#  'Vergo',
#  'Trebol',
#  'Diamante',
#  'Pica',
#  'Senor_Pink',
#  'Buffalo',
#  'Baby_5',
#  'Issho',
#  'Raizo',
#  'Carrot',
#  'Pedro',
#  'Wanda',
#  'Inuarashi',
#  'Nekomamushi',
#  'Pekoms',
#  'Zunesha',
#  'Capone_Bege',
#  'Kaidou',
#  'Jack',
#  'Charlotte_Linlin',
#  'Vinsmoke_Judge',
#  'Charlotte_Katakuri',
#  'Charlotte_Pudding',
#  'Charlotte_Cracker',
#  'Charlotte_Smoothie',
#  'Charlotte_Perospero',
#  'Kozuki_Oden',
#  'Kozuki_Hiyori',
#  'Kikunojo',
#  'Denjiro',
#  'Ashura_Doji',
#  'Kawamatsu',
#  'Shinobu',
#  'Hyogoro',
#  'Shimotsuki_Yasuie',
#  'Yamato',
#  'King',
#  'Queen',
#  'Who%27s-Who',
#  'Black_Maria',
#  'Sasaki',
#  'Page_One',
#  'Ulti',
#  'Scratchmen_Apoo',
#  'Numbers',
#  'One_Piece:_Stampede',
#  'One_Piece_Volume_10089',
#  'Cidre_Guild_Arc',
#  'Monkey_D._Luffy',
#  'Trafalgar_D._Water_Law',
#  'Sabo',
#  'Boa_Hancock',
#  'Buggy',
#  'Smoker',
#  'Rob_Lucci',
#  'Crocodile',
#  'Douglas_Bullet',
#  'Buena_Festa',
#  'Donald_Moderate',
#  'Ann',
#  'Cidre',
#  'Guarana',
#  'Ginger',
#  'Gol_D._Roger',
#  'Pirates_Festival',
#  'Delta_Island',
#  'Gasha_Gasha_no_Mi',
#  'Bijo_Bijo_no_Mi',
#  'Cidre_Guild',
#  'Blog:Recent_posts',
#  'One_Piece_(Manga)',
#  'One_Piece_(Anime)',
#  'Eiichiro_Oda',
#  'Artificial_Devil_Fruit',
#  'Devil_Fruit',
#  'Vegapunk',
#  'SMILE',
#  'Caesar_Clown',
#  'Artificial_Devil_Fruit',
#  'Marshall_D._Teach',
#  'Template:Current_Events/Manga',
#  'Chapter_1044',
#  'Monkey_D._Luffy',
#  'Five_Elders',
#  'Nika',
#  'Gomu_Gomu_no_Mi',
#  'Kozuki_Hiyori',
#  'Kurozumi_Orochi',
#  'Kazenbo',
#  'Kaidou',
#  'Gomu_Gomu_no_Mi/Gear_Fifth_Techniques',
#  'Chapter_1044',
#  'Template:Current_Events/Anime',
#  'Episode_1013',
#  'Episode_1013',
#  'Episode_1014',
#  'Blog:Recent_Blog_Posts',
#  'FUNimation',
#  'Saru',
#  'Real-Life_Timeline',
#  'Aim!_The_King_of_Belly',
#  'Real-Life_Timeline',
#  'Episode_187',
#  'Episode_188',
#  'Real-Life_Timeline',
#  'Chapter_360',
#  'Real-Life_Timeline',
#  'Episode_444',
#  'Real-Life_Timeline',
#  'Episode_967',
#  'One_Piece_(Manga)',
#  'One_Piece_Movies',
#  'List_of_Locations',
#  'World_Timeline',
#  'List_of_Canon_Characters',
#  'Animal_Species',
#  'One_Piece_Merchandise',
#  'One_Piece_Voice_Actors',
#  'Template:Releases',
#  'Template:Releases',
#  'Volume_101',
#  'Home_Video_Releases/Seasons_16-20#Season_20',
#  'Volume_99',
#  'FUNimation/Seasons_10-12#Season_11',
#  'Montblanc_Noland',
#  'Pumpkins',
#  'Jaya',
#  'Arabasta',
#  'Arabasta',
#  'Cavendish',
#  'Mythbusters',
#  'MediaWiki:Uploadtext',
#  'Template_talk:Straw_Hat_Pirates_Gallery',
#  'One_Piece_Wiki_talk:Image_Crew',
#  'Template_talk:Char_Box',
#  'Template_talk:ChapterPages',
#  'One_Piece_Wiki_talk:Guidebook/Spoiler_Rules',
#  'Template_talk:Chapter_Box',
#  'One_Piece_Wiki_talk:Guidebook/Manual_of_Style']

# %%
tag_list_final = list(set(tag_list_final))
tag_list_final
# Out:
# ['Krieg',
#  'Fight_Together',
#  'Pekoms',
#  'Marianne',
#  'Charlotte_Linlin',
#  'Galdino',
#  'Inuarashi',
#  'FUNimation',
#  'Episode_of_East_Blue',
#  'Emporio_Ivankov',
#  'Template_talk:ChapterPages',
#  'Charlotte_Katakuri',
#  'Hard_Knock_Days',
#  'Gedatsu',
#  'Pedro',
#  'Baron_Omatsuri_and_the_Secret_Island',
#  'CP9%27s_Independent_Report',
#  'Gedatsu%27s_Accidental_Blue-Sea_Life',
#  'The_Cursed_Holy_Sword',
#  'Senor_Pink',
#  'Episode_of_Sky_Island',
#  'Sakazuki',
#  'Mythbusters',
#  'Jack',
#  'Ruluka_Island_Arc',
#  'One_Piece_Yellow:_Grand_Elements',
#  'We_Can!',
#  'Caesar_Clown',
#  'Aim!_The_King_of_Belly',
#  'Monkey_D._Luffy',
#  'One_Piece_Red:_Grand_Characters',
#  'Zoan',
#  'Yosaku',
#  'One_Piece_Wiki_talk:Guidebook/Spoiler_Rules',
#  'Artificial_Devil_Fruit',
#  'Karoo',
#  'Hatchan',
#  'Caribou',
#  'Gan_Fall',
#  'Oars',
#  'Grand_Line',
#  'Pagaya',
#  'Trebol',
#  'Kurozumi_Orochi',
#  'Devil_Fruit',
#  'Raizo',
#  'One_Piece_Wiki_talk:Guidebook/Manual_of_Style',
#  'Buffalo',
#  'Caribou%27s_Kehihihihi_in_the_New_World',
#  'Z%27s_Ambition_Arc',
#  'One_Piece:_The_Movie',
#  'Black_Maria',
#  'Scratchmen_Apoo',
#  'Marines',
#  'One_Piece_Film_Z_OST',
#  'Kaze_wo_Sagashite',
#  'PAINT',
#  'Zala',
#  'Ashura_Doji',
#  'Ocean%27s_Dream_Arc',
#  'Nefertari_Cobra',
#  'Caesar_Retrieval_Arc',
#  'Douglas_Bullet',
#  'Episode_of_Alabasta:_The_Desert_Princess_and_the_Pirates',
#  'Silver_Mine_Arc',
#  'Crazy_Rainbow',
#  'Bentham',
#  'Jinbe',
#  'Franky',
#  'Ginger',
#  'Saru',
#  'Brogy',
#  'Shyarly',
#  'Warship_Island_Arc',
#  'Trafalgar_D._Water_Law',
#  'Pumpkins',
#  'Super_Powers',
#  'Kin%27emon',
#  'Gin',
#  'Kuzan',
#  'Arlong',
#  'Kurozumi_Kanjuro',
#  'Mont_Blanc_Cricket',
#  'One_Piece_(Manga)',
#  'Kawamatsu',
#  'Zeff',
#  'Guarana',
#  'Charlos',
#  'One_Piece_Film:_Red',
#  'Jabra',
#  'Marine_Rookie_Arc',
#  'Cavendish',
#  'Bartolomeo',
#  'Miss_Goldenweek%27s_%22Operation:_Meet_Baroque_Works%22',
#  'Igaram',
#  'BON_VOYAGE!',
#  'Dalton',
#  'Heart_of_Gold',
#  'Kazenbo',
#  'Little_East_Blue_Arc',
#  'Nekomamushi',
#  'One_day',
#  'Zunesha',
#  'Animal_Species',
#  'Blog:Recent_Blog_Posts',
#  'Foxy%27s_Return_Arc',
#  'Charlotte_Lola',
#  'Shinobu',
#  'Nojiko',
#  'Alvida',
#  'Keimi',
#  'Hyouzou',
#  'Episode_1014',
#  'Wapol',
#  'Kumadori',
#  'Gasha_Gasha_no_Mi',
#  'DREAMIN%27_ON',
#  'The_Giant_Mechanical_Soldier_of_Karakuri_Castle',
#  'Episode_of_Merry',
#  'Carrot',
#  'Enel',
#  'Episode_188',
#  'Gol_D._Roger',
#  'Ohm',
#  'Iceburg',
#  'Kozuki_Hiyori',
#  'Wyper',
#  'Bartholomew_Kuma',
#  'One_Piece_Film:_Z',
#  'One_Piece_Volume_10089',
#  'Portgas_D._Ace',
#  'Arabasta',
#  'Diary_of_Coby-Meppo',
#  'Kalgara',
#  'Charlotte_Cracker',
#  'Buena_Festa',
#  'One_Piece:_Stampede',
#  'One_Piece_(Anime)',
#  'List_of_Canon_Characters',
#  'Shimotsuki_Yasuie',
#  'One_Piece_Merchandise',
#  'Paramecia',
#  'Cidre_Guild_Arc',
#  'New_World',
#  'Nami',
#  'Logia',
#  'Edward_Newgate',
#  'Charlotte_Perospero',
#  'The_Stories_of_the_Self-Proclaimed_Straw_Hat_Grand_Fleet',
#  'Silvers_Rayleigh',
#  'One_Piece_3D:_Straw_Hat_Chase',
#  'Wake_up!',
#  'Chadros_Higelyges',
#  'Usopp',
#  'Dead_End_Adventure',
#  'From_the_Decks_of_the_World:_The_500,000,000_Man_Arc',
#  'Ann',
#  'Kozuki_Momonosuke',
#  'Dracule_Mihawk',
#  'Magellan',
#  'Devil_Fruit#Natural_Devil_Fruits',
#  'Absalom',
#  'Ryuma',
#  'Borsalino',
#  'Helmeppo',
#  'Donquixote_Doflamingo',
#  'Vergo',
#  'Denjiro',
#  'Solo_Journey_of_Jinbe,_Knight_of_the_Sea',
#  'Post-Alabasta_Arc',
#  'Shirahoshi',
#  'Numbers',
#  'Shura',
#  'Surume',
#  'Kozuki_Oden',
#  'Buggy%27s_Crew:_After_the_Battle!',
#  'Higuma',
#  'Ice_Hunter_Arc',
#  '%22Gang%22_Bege%27s_Oh_My_Family',
#  'Gem',
#  'One_Piece_Film:_Gold',
#  'Kaidou',
#  'Roronoa_Zoro',
#  'Kaya',
#  'Kikunojo',
#  '3D2Y',
#  'Mikita',
#  'Aisa',
#  'Marco',
#  'Sabo',
#  'One_Piece_Film:_Strong_World',
#  'Queen',
#  'Donald_Moderate',
#  'Pirates',
#  'Straw_Hat%27s_Separation_Serial',
#  'Sentomaru',
#  'MediaWiki:Uploadtext',
#  'Nico_Robin',
#  'Glorious_Island',
#  'Cidre_Guild',
#  'Kokoro_no_Chizu',
#  'Hope',
#  'Momonga',
#  'Chapter_360',
#  'Gekko_Moriah',
#  'Episode_187',
#  'Satori',
#  'Capone_Bege',
#  'Template_talk:Chapter_Box',
#  'Pirates_Festival',
#  'Kalifa',
#  'Who%27s-Who',
#  'Kuro',
#  'Episode_of_Luffy',
#  'Charlotte_Smoothie',
#  'Koby',
#  'We_Are!',
#  'Worst_Generation',
#  'Real-Life_Timeline',
#  'Bellamy',
#  'Chapter_1044',
#  'Episode_of_Sabo',
#  'Wapol%27s_Omnivorous_Hurrah',
#  'OVER_THE_TOP',
#  'Believe',
#  'One_Piece_Blue:_Grand_Data_File',
#  'Hatchan%27s_Sea-Floor_Stroll',
#  'Hody_Jones',
#  'Jaya',
#  'Episode_of_Nami',
#  'Nika',
#  'Smoker',
#  'Fukurou',
#  'Pappug',
#  'Galley-La_Company',
#  'Baby_5',
#  'Bell-m%C3%A8re',
#  'One_Piece_Green:_Secret_Pieces',
#  'Goat_Island_Arc',
#  'Chopper%27s_Kingdom_on_the_Island_of_Strange_Animals',
#  'One_Piece_Blue_Deep:_Characters_World',
#  'Blueno',
#  'Conis',
#  'One_Piece_Movies',
#  'Blog:Recent_posts',
#  'Dorry',
#  'Four_Emperors',
#  'Clockwork_Island_Adventure',
#  'Cidre',
#  'Home_Video_Releases/Seasons_16-20#Season_20',
#  'Spandam',
#  'Delta_Island',
#  'King',
#  'Ulti',
#  'Kaku',
#  'Template_talk:Straw_Hat_Pirates_Gallery',
#  'Vander_Decken_IX',
#  'Revolutionary_Army',
#  'Gaimon',
#  'Monet',
#  'FUNimation/Seasons_10-12#Season_11',
#  'Share_the_World',
#  'Ace%27s_Great_Blackbeard_Search',
#  'Hyogoro',
#  'Johnny',
#  'Gomu_Gomu_no_Mi',
#  'Episode_of_Chopper_Plus:_Bloom_in_Winter,_Miracle_Sakura',
#  'SMILE',
#  'Vinsmoke_Judge',
#  'Hands_Up!',
#  'World_Timeline',
#  'East_Blue',
#  'One_Piece_Soundtracks',
#  'Hikari_e',
#  'World_Government',
#  'Adventure_of_Nebulandia',
#  'Vivre_Card_-_One_Piece_Visual_Dictionary',
#  'Wanda',
#  'Gomu_Gomu_no_Mi/Gear_Fifth_Techniques',
#  'We_Go!',
#  'Rob_Lucci',
#  'Shanks',
#  'Sanji',
#  'Neptune',
#  'Straw_Hat_Pirates',
#  'Paulie',
#  'One_Piece_Voice_Actors',
#  'Volume_99',
#  'Charlotte_Pudding',
#  'One_Piece_Wiki_talk:Image_Crew',
#  'Eiichiro_Oda',
#  'Laboon',
#  'Episode_967',
#  'Jungle_P',
#  'Kohza',
#  'Template:Current_Events/Manga',
#  'Five_Elders',
#  'Episode_444',
#  'Sasaki',
#  'Hannyabal',
#  'Brook',
#  'Kureha',
#  'Marshall_D._Teach',
#  'Tony_Tony_Chopper',
#  'Riku_Doldo_III',
#  'Page_One',
#  'Boa_Hancock',
#  'Seven_Warlords_of_the_Sea',
#  'Daz_Bonez',
#  'Volume_101',
#  'Pica',
#  'Foxy',
#  'Diamante',
#  'Brand_New_World',
#  'Template_talk:Char_Box',
#  'Kyros',
#  'Perona',
#  'Bijo_Bijo_no_Mi',
#  'Rebecca',
#  'Spa_Island_Arc',
#  'Morgan',
#  'Hogback',
#  'Kokoro',
#  'Template:Current_Events/Anime',
#  'Duval',
#  'Yamato',
#  'Buggy',
#  'Nefertari_Vivi',
#  'Vegapunk',
#  'Episode_1013',
#  'Montblanc_Noland',
#  'List_of_Locations',
#  'Issho',
#  'Jango%27s_Dance_Paradise',
#  'G-8_Arc',
#  'From_the_Decks_of_the_World',
#  'Template:Releases',
#  'Crocodile',
#  'List_of_Non-Canon_Characters',
#  'Franky_Family',
#  'Enel%27s_Great_Space_Operations']

# %%
tag_list_final = [unquote(t) for t in tag_list_final]
tag_list_final
# Out:
# ['Krieg',
#  'Fight_Together',
#  'Pekoms',
#  'Marianne',
#  'Charlotte_Linlin',
#  'Galdino',
#  'Inuarashi',
#  'FUNimation',
#  'Episode_of_East_Blue',
#  'Emporio_Ivankov',
#  'Template_talk:ChapterPages',
#  'Charlotte_Katakuri',
#  'Hard_Knock_Days',
#  'Gedatsu',
#  'Pedro',
#  'Baron_Omatsuri_and_the_Secret_Island',
#  "CP9's_Independent_Report",
#  "Gedatsu's_Accidental_Blue-Sea_Life",
#  'The_Cursed_Holy_Sword',
#  'Senor_Pink',
#  'Episode_of_Sky_Island',
#  'Sakazuki',
#  'Mythbusters',
#  'Jack',
#  'Ruluka_Island_Arc',
#  'One_Piece_Yellow:_Grand_Elements',
#  'We_Can!',
#  'Caesar_Clown',
#  'Aim!_The_King_of_Belly',
#  'Monkey_D._Luffy',
#  'One_Piece_Red:_Grand_Characters',
#  'Zoan',
#  'Yosaku',
#  'One_Piece_Wiki_talk:Guidebook/Spoiler_Rules',
#  'Artificial_Devil_Fruit',
#  'Karoo',
#  'Hatchan',
#  'Caribou',
#  'Gan_Fall',
#  'Oars',
#  'Grand_Line',
#  'Pagaya',
#  'Trebol',
#  'Kurozumi_Orochi',
#  'Devil_Fruit',
#  'Raizo',
#  'One_Piece_Wiki_talk:Guidebook/Manual_of_Style',
#  'Buffalo',
#  "Caribou's_Kehihihihi_in_the_New_World",
#  "Z's_Ambition_Arc",
#  'One_Piece:_The_Movie',
#  'Black_Maria',
#  'Scratchmen_Apoo',
#  'Marines',
#  'One_Piece_Film_Z_OST',
#  'Kaze_wo_Sagashite',
#  'PAINT',
#  'Zala',
#  'Ashura_Doji',
#  "Ocean's_Dream_Arc",
#  'Nefertari_Cobra',
#  'Caesar_Retrieval_Arc',
#  'Douglas_Bullet',
#  'Episode_of_Alabasta:_The_Desert_Princess_and_the_Pirates',
#  'Silver_Mine_Arc',
#  'Crazy_Rainbow',
#  'Bentham',
#  'Jinbe',
#  'Franky',
#  'Ginger',
#  'Saru',
#  'Brogy',
#  'Shyarly',
#  'Warship_Island_Arc',
#  'Trafalgar_D._Water_Law',
#  'Pumpkins',
#  'Super_Powers',
#  "Kin'emon",
#  'Gin',
#  'Kuzan',
#  'Arlong',
#  'Kurozumi_Kanjuro',
#  'Mont_Blanc_Cricket',
#  'One_Piece_(Manga)',
#  'Kawamatsu',
#  'Zeff',
#  'Guarana',
#  'Charlos',
#  'One_Piece_Film:_Red',
#  'Jabra',
#  'Marine_Rookie_Arc',
#  'Cavendish',
#  'Bartolomeo',
#  'Miss_Goldenweek\'s_"Operation:_Meet_Baroque_Works"',
#  'Igaram',
#  'BON_VOYAGE!',
#  'Dalton',
#  'Heart_of_Gold',
#  'Kazenbo',
#  'Little_East_Blue_Arc',
#  'Nekomamushi',
#  'One_day',
#  'Zunesha',
#  'Animal_Species',
#  'Blog:Recent_Blog_Posts',
#  "Foxy's_Return_Arc",
#  'Charlotte_Lola',
#  'Shinobu',
#  'Nojiko',
#  'Alvida',
#  'Keimi',
#  'Hyouzou',
#  'Episode_1014',
#  'Wapol',
#  'Kumadori',
#  'Gasha_Gasha_no_Mi',
#  "DREAMIN'_ON",
#  'The_Giant_Mechanical_Soldier_of_Karakuri_Castle',
#  'Episode_of_Merry',
#  'Carrot',
#  'Enel',
#  'Episode_188',
#  'Gol_D._Roger',
#  'Ohm',
#  'Iceburg',
#  'Kozuki_Hiyori',
#  'Wyper',
#  'Bartholomew_Kuma',
#  'One_Piece_Film:_Z',
#  'One_Piece_Volume_10089',
#  'Portgas_D._Ace',
#  'Arabasta',
#  'Diary_of_Coby-Meppo',
#  'Kalgara',
#  'Charlotte_Cracker',
#  'Buena_Festa',
#  'One_Piece:_Stampede',
#  'One_Piece_(Anime)',
#  'List_of_Canon_Characters',
#  'Shimotsuki_Yasuie',
#  'One_Piece_Merchandise',
#  'Paramecia',
#  'Cidre_Guild_Arc',
#  'New_World',
#  'Nami',
#  'Logia',
#  'Edward_Newgate',
#  'Charlotte_Perospero',
#  'The_Stories_of_the_Self-Proclaimed_Straw_Hat_Grand_Fleet',
#  'Silvers_Rayleigh',
#  'One_Piece_3D:_Straw_Hat_Chase',
#  'Wake_up!',
#  'Chadros_Higelyges',
#  'Usopp',
#  'Dead_End_Adventure',
#  'From_the_Decks_of_the_World:_The_500,000,000_Man_Arc',
#  'Ann',
#  'Kozuki_Momonosuke',
#  'Dracule_Mihawk',
#  'Magellan',
#  'Devil_Fruit#Natural_Devil_Fruits',
#  'Absalom',
#  'Ryuma',
#  'Borsalino',
#  'Helmeppo',
#  'Donquixote_Doflamingo',
#  'Vergo',
#  'Denjiro',
#  'Solo_Journey_of_Jinbe,_Knight_of_the_Sea',
#  'Post-Alabasta_Arc',
#  'Shirahoshi',
#  'Numbers',
#  'Shura',
#  'Surume',
#  'Kozuki_Oden',
#  "Buggy's_Crew:_After_the_Battle!",
#  'Higuma',
#  'Ice_Hunter_Arc',
#  '"Gang"_Bege\'s_Oh_My_Family',
#  'Gem',
#  'One_Piece_Film:_Gold',
#  'Kaidou',
#  'Roronoa_Zoro',
#  'Kaya',
#  'Kikunojo',
#  '3D2Y',
#  'Mikita',
#  'Aisa',
#  'Marco',
#  'Sabo',
#  'One_Piece_Film:_Strong_World',
#  'Queen',
#  'Donald_Moderate',
#  'Pirates',
#  "Straw_Hat's_Separation_Serial",
#  'Sentomaru',
#  'MediaWiki:Uploadtext',
#  'Nico_Robin',
#  'Glorious_Island',
#  'Cidre_Guild',
#  'Kokoro_no_Chizu',
#  'Hope',
#  'Momonga',
#  'Chapter_360',
#  'Gekko_Moriah',
#  'Episode_187',
#  'Satori',
#  'Capone_Bege',
#  'Template_talk:Chapter_Box',
#  'Pirates_Festival',
#  'Kalifa',
#  "Who's-Who",
#  'Kuro',
#  'Episode_of_Luffy',
#  'Charlotte_Smoothie',
#  'Koby',
#  'We_Are!',
#  'Worst_Generation',
#  'Real-Life_Timeline',
#  'Bellamy',
#  'Chapter_1044',
#  'Episode_of_Sabo',
#  "Wapol's_Omnivorous_Hurrah",
#  'OVER_THE_TOP',
#  'Believe',
#  'One_Piece_Blue:_Grand_Data_File',
#  "Hatchan's_Sea-Floor_Stroll",
#  'Hody_Jones',
#  'Jaya',
#  'Episode_of_Nami',
#  'Nika',
#  'Smoker',
#  'Fukurou',
#  'Pappug',
#  'Galley-La_Company',
#  'Baby_5',
#  'Bell-mère',
#  'One_Piece_Green:_Secret_Pieces',
#  'Goat_Island_Arc',
#  "Chopper's_Kingdom_on_the_Island_of_Strange_Animals",
#  'One_Piece_Blue_Deep:_Characters_World',
#  'Blueno',
#  'Conis',
#  'One_Piece_Movies',
#  'Blog:Recent_posts',
#  'Dorry',
#  'Four_Emperors',
#  'Clockwork_Island_Adventure',
#  'Cidre',
#  'Home_Video_Releases/Seasons_16-20#Season_20',
#  'Spandam',
#  'Delta_Island',
#  'King',
#  'Ulti',
#  'Kaku',
#  'Template_talk:Straw_Hat_Pirates_Gallery',
#  'Vander_Decken_IX',
#  'Revolutionary_Army',
#  'Gaimon',
#  'Monet',
#  'FUNimation/Seasons_10-12#Season_11',
#  'Share_the_World',
#  "Ace's_Great_Blackbeard_Search",
#  'Hyogoro',
#  'Johnny',
#  'Gomu_Gomu_no_Mi',
#  'Episode_of_Chopper_Plus:_Bloom_in_Winter,_Miracle_Sakura',
#  'SMILE',
#  'Vinsmoke_Judge',
#  'Hands_Up!',
#  'World_Timeline',
#  'East_Blue',
#  'One_Piece_Soundtracks',
#  'Hikari_e',
#  'World_Government',
#  'Adventure_of_Nebulandia',
#  'Vivre_Card_-_One_Piece_Visual_Dictionary',
#  'Wanda',
#  'Gomu_Gomu_no_Mi/Gear_Fifth_Techniques',
#  'We_Go!',
#  'Rob_Lucci',
#  'Shanks',
#  'Sanji',
#  'Neptune',
#  'Straw_Hat_Pirates',
#  'Paulie',
#  'One_Piece_Voice_Actors',
#  'Volume_99',
#  'Charlotte_Pudding',
#  'One_Piece_Wiki_talk:Image_Crew',
#  'Eiichiro_Oda',
#  'Laboon',
#  'Episode_967',
#  'Jungle_P',
#  'Kohza',
#  'Template:Current_Events/Manga',
#  'Five_Elders',
#  'Episode_444',
#  'Sasaki',
#  'Hannyabal',
#  'Brook',
#  'Kureha',
#  'Marshall_D._Teach',
#  'Tony_Tony_Chopper',
#  'Riku_Doldo_III',
#  'Page_One',
#  'Boa_Hancock',
#  'Seven_Warlords_of_the_Sea',
#  'Daz_Bonez',
#  'Volume_101',
#  'Pica',
#  'Foxy',
#  'Diamante',
#  'Brand_New_World',
#  'Template_talk:Char_Box',
#  'Kyros',
#  'Perona',
#  'Bijo_Bijo_no_Mi',
#  'Rebecca',
#  'Spa_Island_Arc',
#  'Morgan',
#  'Hogback',
#  'Kokoro',
#  'Template:Current_Events/Anime',
#  'Duval',
#  'Yamato',
#  'Buggy',
#  'Nefertari_Vivi',
#  'Vegapunk',
#  'Episode_1013',
#  'Montblanc_Noland',
#  'List_of_Locations',
#  'Issho',
#  "Jango's_Dance_Paradise",
#  'G-8_Arc',
#  'From_the_Decks_of_the_World',
#  'Template:Releases',
#  'Crocodile',
#  'List_of_Non-Canon_Characters',
#  'Franky_Family',
#  "Enel's_Great_Space_Operations"]

# %% [markdown]
# © 2020 Institute of Data
