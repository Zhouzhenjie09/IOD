# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.2: Feature Selection

# %% [markdown]
# ## Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Read CSV
wine_csv = 'C:/Users/user/Documents/IOD_data_MAIN/DATA/winequality_merged.csv'
wine = pd.read_csv(wine_csv)

# %% [markdown]
# ## Explore Data (Exploratory Data Analysis)

# %%
# ANSWER
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# 1      9.8        5         1
# 2      9.8        5         1
# 3      9.8        6         1
# 4      9.4        5         1

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  red_wine              6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# red_wine                0
# dtype: int64

# %%
wine.duplicated().sum()
# Out:
# 1177

# %%
duplicate_wine = wine.duplicated()
duplicates = wine[duplicate_wine]
print(duplicates)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 6427            6.4             0.230         0.35           10.30      0.042
# 6449            7.0             0.360         0.35            2.50      0.048
# 6450            6.4             0.330         0.44            8.90      0.055
# 6455            7.1             0.230         0.39           13.70      0.058
# 6479            6.6             0.340         0.40            8.10      0.046
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 6427                 54.0                 140.0  0.99670  3.23       0.47
# 6449                 67.0                 161.0  0.99146  3.05       0.56
# 6450                 52.0                 164.0  0.99488  3.10       0.48
# 6455                 26.0                 172.0  0.99755  2.90       0.46
# 6479                 68.0                 170.0  0.99494  3.15       0.50
#
#         alcohol  quality  red_wine
# 4      9.400000        5         1
# 11    10.500000        5         1
# 27     9.500000        5         1
# 40    10.500000        5         1
# 65    10.900000        5         1
# ...         ...      ...       ...
# 6427   9.200000        5         0
# 6449  11.100000        6         0
# 6450   9.600000        5         0
# 6455   9.000000        6         0
# 6479   9.533333        6         0
#
# [1177 rows x 13 columns]

# %%
wine.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  red_wine
# 0         9.4        5         1
# 1         9.8        5         1
# 2         9.8        5         1
# 3         9.8        6         1
# 5         9.4        5         1
# ...       ...      ...       ...
# 6492     11.2        6         0
# 6493      9.6        5         0
# 6494      9.4        6         0
# 6495     12.8        7         0
# 6496     11.8        6         0
#
# [5320 rows x 13 columns]

# %%
sns.pairplot(wine, hue="red_wine")

# %%
abs(wine.corr()['quality']).sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.444319
# density                 0.305858
# volatile acidity        0.265699
# chlorides               0.200666
# red_wine                0.119323
# citric acid             0.085532
# fixed acidity           0.076743
# free sulfur dioxide     0.055463
# total sulfur dioxide    0.041385
# sulphates               0.038485
# residual sugar          0.036980
# pH                      0.019506
# Name: quality, dtype: float64

# %% [markdown]
# ## Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
# Target Variable
y = wine['quality']

# %% [markdown]
# # Set Predictor Variables based on correlation

# %% [markdown]
# Create a predictor matrix with variables of your choice. State your reason.

# %%
# ANSWER
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
# red_wine                   -0.348821   0.512678            -0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
# red_wine                         -0.700357  0.390645  0.329129   0.487218
#
#                        alcohol   quality  red_wine
# fixed acidity        -0.095452 -0.076743  0.486740
# volatile acidity     -0.037640 -0.265699  0.653036
# citric acid          -0.010493  0.085532 -0.187397
# residual sugar       -0.359415 -0.036980 -0.348821
# chlorides            -0.256916 -0.200666  0.512678
# free sulfur dioxide  -0.179838  0.055463 -0.471644
# total sulfur dioxide -0.265740 -0.041385 -0.700357
# density              -0.686745 -0.305858  0.390645
# pH                    0.121248  0.019506  0.329129
# sulphates            -0.003029  0.038485  0.487218
# alcohol               1.000000  0.444319 -0.032970
# quality               0.444319  1.000000 -0.119323
# red_wine             -0.032970 -0.119323  1.000000

# %%
x.describe()
# Out:
#            density     red_wine    chlorides  volatile acidity      alcohol
# count  6497.000000  6497.000000  6497.000000       6497.000000  6497.000000
# mean      0.994697     0.246114     0.056034          0.339666    10.491801
# std       0.002999     0.430779     0.035034          0.164636     1.192712
# min       0.987110     0.000000     0.009000          0.080000     8.000000
# 25%       0.992340     0.000000     0.038000          0.230000     9.500000
# 50%       0.994890     0.000000     0.047000          0.290000    10.300000
# 75%       0.996990     0.000000     0.065000          0.400000    11.300000
# max       1.038980     1.000000     0.611000          1.580000    14.900000

# %% [markdown]
# # Using Linear Regression model
#
# Reference: http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = wine[['alcohol']]
y = wine[['quality']]


# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
# Create a model for Linear Regression
lr = LinearRegression().fit(X_train, y_train)
print(lr.coef_, lr.intercept_)

# Fit the model with the Training data
print(lr.predict(X_test))

# Calculate the score (R^2 for Regression) for Training Data
print(lr.score(X_train, y_train))

# Calculate the score (R^2 for Regression) for Testing Data
print(lr.score(X_test, y_test))
# Out:
# [[32.32184936  0.15835211 -0.63881848 -1.70128938  0.37360717]] [-29.68145177]
# [[6.69297232]
#  [5.21723033]
#  [6.19270824]
#  ...
#  [6.63858903]
#  [5.38609922]
#  [5.53491779]]
# 0.2733243040185741
# 0.2550516332495344

# %% [markdown]
# # Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# ### Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# ### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# ### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$

# %%
X = wine.drop(columns=['quality'])
y = wine[['quality']]

print(X.shape, y.shape)
# Out:
# (6497, 12) (6497, 1)

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5197, 12)
# (5197, 1)
# (1300, 12)
# (1300, 1)

# %%
## Flag intermediate output
show_steps = True   # for testing/debugging

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression
# get the number of cases in the test data
n = X_test.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

       # fit the model with the Training data
        fit =  model.fit(X_train[included + [new_column]], y_train) # fit a model; consider which predictors should be included
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_test[included + [new_column]], y_test) # calculate the score
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - (((1- r2)*(n-1))/(n-k-1)) # calculate the Adjusted R^2

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = free sulfur dioxide, residual sugar, citric acid, pH, total sulfur dioxide, red_wine, density, fixed acidity, sulphates, chlorides, volatile acidity, alcohol
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = -0.001; Best = 0.000
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = -0.002; Best = 0.000
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.007; Best = 0.000
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.008; Adjusted R^2 = 0.007
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = -0.001; Best = 0.007
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = -0.003; Best = 0.007
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.021; Best = 0.007
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.021; Adjusted R^2 = 0.021
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.102; Best = 0.021
# (Step) - New Best!   : Feature = density; R^2 = 0.103; Adjusted R^2 = 0.102
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.011; Best = 0.102
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = -0.003; Best = 0.102
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.053; Best = 0.102
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.075; Best = 0.102
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.181; Best = 0.102
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.182; Adjusted R^2 = 0.181
# Added feature alcohol with R^2 = 0.182 and adjusted R^2 = 0.181
#
# (Step) Excluded = free sulfur dioxide, residual sugar, citric acid, pH, total sulfur dioxide, red_wine, density, fixed acidity, sulphates, chlorides, volatile acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.190; Best = 0.181
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.191; Adjusted R^2 = 0.190
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.198; Best = 0.190
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.199; Adjusted R^2 = 0.198
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.189; Best = 0.198
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.182; Best = 0.198
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.189; Best = 0.198
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.196; Best = 0.198
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.180; Best = 0.198
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.183; Best = 0.198
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.179; Best = 0.198
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.193; Best = 0.198
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.249; Best = 0.198
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.250; Adjusted R^2 = 0.249
# Added feature volatile acidity with R^2 = 0.250 and adjusted R^2 = 0.249
#
# (Step) Excluded = free sulfur dioxide, residual sugar, citric acid, pH, total sulfur dioxide, red_wine, density, fixed acidity, sulphates, chlorides
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.247; Best = 0.249
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.252; Best = 0.249
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.254; Adjusted R^2 = 0.252
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.248; Best = 0.252
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.249; Best = 0.252
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.249; Best = 0.252
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.252; Best = 0.252
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.250; Best = 0.252
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.247; Best = 0.252
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.252; Best = 0.252
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.248; Best = 0.252
# Added feature residual sugar with R^2 = 0.254 and adjusted R^2 = 0.252
#
# (Step) Excluded = free sulfur dioxide, pH, citric acid, sulphates, total sulfur dioxide, density, fixed acidity, red_wine, chlorides
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.251; Best = 0.252
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.253; Best = 0.252
# (Step) - New Best!   : Feature = pH; R^2 = 0.256; Adjusted R^2 = 0.253
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.252; Best = 0.253
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, residual sugar, sulphates
# (Step) - Adjusted R^2: This = 0.257; Best = 0.253
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.259; Adjusted R^2 = 0.257
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.255; Best = 0.257
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, residual sugar, density
# (Step) - Adjusted R^2: This = 0.251; Best = 0.257
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.250; Best = 0.257
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.259; Best = 0.257
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.261; Adjusted R^2 = 0.259
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.251; Best = 0.259
# Added feature red_wine with R^2 = 0.261 and adjusted R^2 = 0.259
#
# (Step) Excluded = free sulfur dioxide, pH, citric acid, total sulfur dioxide, density, fixed acidity, sulphates, chlorides
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.256; Best = 0.259
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.259; Best = 0.259
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.259; Best = 0.259
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.258; Best = 0.259
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.261; Best = 0.259
# (Step) - New Best!   : Feature = density; R^2 = 0.264; Adjusted R^2 = 0.261
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.259; Best = 0.261
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, sulphates
# (Step) - Adjusted R^2: This = 0.259; Best = 0.261
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.259; Best = 0.261
# Added feature density with R^2 = 0.264 and adjusted R^2 = 0.261
#
# (Step) Excluded = free sulfur dioxide, pH, citric acid, total sulfur dioxide, fixed acidity, sulphates, chlorides
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.259; Best = 0.261
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.261; Best = 0.261
# (Step) - New Best!   : Feature = pH; R^2 = 0.265; Adjusted R^2 = 0.261
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.260; Best = 0.261
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.260; Best = 0.261
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.260; Best = 0.261
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates
# (Step) - Adjusted R^2: This = 0.264; Best = 0.261
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.267; Adjusted R^2 = 0.264
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, chlorides
# (Step) - Adjusted R^2: This = 0.261; Best = 0.264
# Added feature sulphates with R^2 = 0.267 and adjusted R^2 = 0.264
#
# (Step) Excluded = free sulfur dioxide, pH, citric acid, total sulfur dioxide, fixed acidity, chlorides
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.261; Best = 0.264
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, pH
# (Step) - Adjusted R^2: This = 0.264; Best = 0.264
# (Step) - New Best!   : Feature = pH; R^2 = 0.268; Adjusted R^2 = 0.264
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.263; Best = 0.264
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.264; Best = 0.264
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.263; Best = 0.264
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.266; Best = 0.264
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.270; Adjusted R^2 = 0.266
# Added feature chlorides with R^2 = 0.270 and adjusted R^2 = 0.266
#
# (Step) Excluded = free sulfur dioxide, pH, citric acid, total sulfur dioxide, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.263; Best = 0.266
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides, pH
# (Step) - Adjusted R^2: This = 0.265; Best = 0.266
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.265; Best = 0.266
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.265; Best = 0.266
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides, fixed acidity
# (Step) - Adjusted R^2: This = 0.265; Best = 0.266
#
# Resulting features:
# alcohol, volatile acidity, residual sugar, red_wine, density, sulphates, chlorides

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression
# get the number of cases in the test data
n = X_test.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))
        
        # fit the model with the Training data
        fit =  model.fit(X_train[included + [new_column]], y_train) # fit a model; consider which predictors should be included
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_test[included + [new_column]], y_test) # calculate the score
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - (((1- r2)*(n-1))/(n-k-1)) # calculate the Adjusted R^2

        if show_steps:
            print('(Step) - R^2: This = %.3f'  %
                  (r2))
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = alcohol
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - R^2: This = 0.182
# (Step) - Adjusted R^2: This = 0.181; Best = 0.000
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.182; Adjusted R^2 = 0.181
# Added feature alcohol with R^2 = 0.182 and adjusted R^2 = 0.181
#
# (Step) Excluded =
#
# Resulting features:
# alcohol

# %%
# fit the model with the Training data
        fit =  model.fit(X_train[included + [new_column]], y_train) # fit a model; consider which predictors should be included
        
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_test[included + [new_column]], y_test) # calculate the score
        # number of predictors in this model
        k = len(included) + 1
        # calculate the adjusted R^2
        adjusted_r2 = 1 - (((1- r2)*(n-1))/(n-k-1)) # calculate the Adjusted R^2

# %% [markdown]
# # Cross validation

# %%
# Answer

from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score


X = wine[included]
y = wine['quality']
model = LinearRegression()
abs(cross_val_score(model, X, y, scoring = 'neg_root_mean_square_error')
# Out:
#   File "<ipython-input-47-9d80b9698434>", line 10
#     abs(cross_val_score(model, X, y, scoring = 'neg_root_mean_square_error')
#                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
from sklearn.metrics import mean_square_error
