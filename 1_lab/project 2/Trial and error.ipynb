# %%
import pandas as pd
import dtale
from pandas_profiling import ProfileReport
import sweetviz
from pandas_visual_analysis import VisualAnalysis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9b1b0f8509ed> in <module>
#       1 import pandas as pd
# ----> 2 import dtale
#       3 from pandas_profiling import ProfileReport
#       4 import sweetviz
#       5 from pandas_visual_analysis import VisualAnalysis
#
# ModuleNotFoundError: No module named 'dtale'

# %%
conda install dtale -c conda-forge
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - dtale
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py38h885f38d_6         381 KB  conda-forge
#     conda-4.11.0               |   py38haa244fe_0        16.9 MB  conda-forge
#     dash-2.0.0                 |     pyhd8ed1ab_0         5.7 MB  conda-forge
#     dash-bootstrap-components-1.0.2|     pyhd8ed1ab_0         106 KB  conda-forge
# Note: you may need to restart the kernel to use updated packages.
#     dash-core-components-2.0.0 |     pyhd8ed1ab_0           7 KB  conda-forge
#     dash-daq-0.5.0             |     pyh9f0ad1d_1         545 KB  conda-forge
#     dash-html-components-2.0.0 |     pyhd8ed1ab_0           7 KB  conda-forge
#     dash_colorscales-0.0.4     |     pyh9f0ad1d_0          59 KB  conda-forge
#     dtale-1.61.1               |     pyhd8ed1ab_0         9.5 MB  conda-forge
#     flask-compress-1.10.1      |     pyhd8ed1ab_0          13 KB  conda-forge
#     lz4-3.1.10                 |   py38h34afd45_0         118 KB  conda-forge
#     missingno-0.4.2            |             py_1          12 KB  conda-forge
#     plotly-5.4.0               |     pyhd8ed1ab_0         6.9 MB  conda-forge
#     ppscore-1.2.0              |     pyhd3deb0d_0          15 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     squarify-0.4.3             |             py_0           7 KB  conda-forge
#     strsimpy-0.1.9             |     pyh9f0ad1d_0          22 KB  conda-forge
#     tenacity-8.0.1             |     pyhd8ed1ab_0          21 KB  conda-forge
#     xarray-0.20.2              |     pyhd8ed1ab_0         628 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        40.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      conda-forge/win-64::brotli-python-1.0.9-py38h885f38d_6
#   dash               conda-forge/noarch::dash-2.0.0-pyhd8ed1ab_0
#   dash-bootstrap-co~ conda-forge/noarch::dash-bootstrap-components-1.0.2-pyhd8ed1ab_0
#   dash-core-compone~ conda-forge/noarch::dash-core-components-2.0.0-pyhd8ed1ab_0
#   dash-daq           conda-forge/noarch::dash-daq-0.5.0-pyh9f0ad1d_1
#   dash-html-compone~ conda-forge/noarch::dash-html-components-2.0.0-pyhd8ed1ab_0
#   dash_colorscales   conda-forge/noarch::dash_colorscales-0.0.4-pyh9f0ad1d_0
#   dtale              conda-forge/noarch::dtale-1.61.1-pyhd8ed1ab_0
#   flask-compress     conda-forge/noarch::flask-compress-1.10.1-pyhd8ed1ab_0
#   lz4                conda-forge/win-64::lz4-3.1.10-py38h34afd45_0
#   missingno          conda-forge/noarch::missingno-0.4.2-py_1
#   plotly             conda-forge/noarch::plotly-5.4.0-pyhd8ed1ab_0
#   ppscore            conda-forge/noarch::ppscore-1.2.0-pyhd3deb0d_0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#   squarify           conda-forge/noarch::squarify-0.4.3-py_0
#   strsimpy           conda-forge/noarch::strsimpy-0.1.9-pyh9f0ad1d_0
#   tenacity           conda-forge/noarch::tenacity-8.0.1-pyhd8ed1ab_0
#   xarray             conda-forge/noarch::xarray-0.20.2-pyhd8ed1ab_0
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\Anaconda3
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.3-py38haa95532_0 --> conda-forge::conda-4.11.0-py38haa244fe_0
#
#
#
# Downloading and Extracting Packages
#
# brotli-python-1.0.9  | 381 KB    |            |   0%
# brotli-python-1.0.9  | 381 KB    | 4          |   4%
# brotli-python-1.0.9  | 381 KB    | #######9   |  80%
# brotli-python-1.0.9  | 381 KB    | ########## | 100%
#
# conda-4.11.0         | 16.9 MB   |            |   0%
# conda-4.11.0         | 16.9 MB   | #1         |  11%
# conda-4.11.0         | 16.9 MB   | ###5       |  35%
# conda-4.11.0         | 16.9 MB   | ######     |  60%
# conda-4.11.0         | 16.9 MB   | ########3  |  83%
# conda-4.11.0         | 16.9 MB   | ########## | 100%
#
# dash-daq-0.5.0       | 545 KB    |            |   0%
# dash-daq-0.5.0       | 545 KB    | ########## | 100%
# dash-daq-0.5.0       | 545 KB    | ########## | 100%
#
# dtale-1.61.1         | 9.5 MB    |            |   0%
# dtale-1.61.1         | 9.5 MB    |            |   0%
# dtale-1.61.1         | 9.5 MB    | 9          |   9%
# dtale-1.61.1         | 9.5 MB    | #7         |  18%
# dtale-1.61.1         | 9.5 MB    | ##6        |  27%
# dtale-1.61.1         | 9.5 MB    | ###6       |  36%
# dtale-1.61.1         | 9.5 MB    | ####4      |  44%
# dtale-1.61.1         | 9.5 MB    | #####4     |  54%
# dtale-1.61.1         | 9.5 MB    | ######4    |  64%
# dtale-1.61.1         | 9.5 MB    | #######3   |  73%
# dtale-1.61.1         | 9.5 MB    | ########1  |  82%
# dtale-1.61.1         | 9.5 MB    | #########  |  91%
# dtale-1.61.1         | 9.5 MB    | ########## | 100%
# dtale-1.61.1         | 9.5 MB    | ########## | 100%
#
# lz4-3.1.10           | 118 KB    |            |   0%
# lz4-3.1.10           | 118 KB    | ########## | 100%
# lz4-3.1.10           | 118 KB    | ########## | 100%
#
# ppscore-1.2.0        | 15 KB     |            |   0%
# ppscore-1.2.0        | 15 KB     | ########## | 100%
# ppscore-1.2.0        | 15 KB     | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
#
# strsimpy-0.1.9       | 22 KB     |            |   0%
# strsimpy-0.1.9       | 22 KB     | #######3   |  73%
# strsimpy-0.1.9       | 22 KB     | ########## | 100%
# strsimpy-0.1.9       | 22 KB     | ########## | 100%
#
# dash_colorscales-0.0 | 59 KB     |            |   0%
# dash_colorscales-0.0 | 59 KB     | ##7        |  27%
# dash_colorscales-0.0 | 59 KB     | ########## | 100%
#
# dash-core-components | 7 KB      |            |   0%
# dash-core-components | 7 KB      | ########## | 100%
# dash-core-components | 7 KB      | ########## | 100%
#
# flask-compress-1.10. | 13 KB     |            |   0%
# flask-compress-1.10. | 13 KB     | ########## | 100%
# flask-compress-1.10. | 13 KB     | ########## | 100%
#
# dash-2.0.0           | 5.7 MB    |            |   0%
# dash-2.0.0           | 5.7 MB    |            |   0%
# dash-2.0.0           | 5.7 MB    | 2          |   3%
# dash-2.0.0           | 5.7 MB    | 9          |   9%
# dash-2.0.0           | 5.7 MB    | ##         |  20%
# dash-2.0.0           | 5.7 MB    | ###8       |  38%
# dash-2.0.0           | 5.7 MB    | ######5    |  66%
# dash-2.0.0           | 5.7 MB    | ########5  |  85%
# dash-2.0.0           | 5.7 MB    | ########## | 100%
#
# dash-bootstrap-compo | 106 KB    |            |   0%
# dash-bootstrap-compo | 106 KB    | #5         |  15%
# dash-bootstrap-compo | 106 KB    | ########## | 100%
# dash-bootstrap-compo | 106 KB    | ########## | 100%
#
# tenacity-8.0.1       | 21 KB     |            |   0%
# tenacity-8.0.1       | 21 KB     | ########## | 100%
# tenacity-8.0.1       | 21 KB     | ########## | 100%
#
# missingno-0.4.2      | 12 KB     |            |   0%
# missingno-0.4.2      | 12 KB     | ########## | 100%
# missingno-0.4.2      | 12 KB     | ########## | 100%
#
# squarify-0.4.3       | 7 KB      |            |   0%
# squarify-0.4.3       | 7 KB      | ########## | 100%
# squarify-0.4.3       | 7 KB      | ########## | 100%
#
# plotly-5.4.0         | 6.9 MB    |            |   0%
# plotly-5.4.0         | 6.9 MB    | #8         |  19%
# plotly-5.4.0         | 6.9 MB    | #####6     |  56%
# plotly-5.4.0         | 6.9 MB    | ########## | 100%
# plotly-5.4.0         | 6.9 MB    | ########## | 100%
#
# dash-html-components | 7 KB      |            |   0%
# dash-html-components | 7 KB      | ########## | 100%
# dash-html-components | 7 KB      | ########## | 100%
#
# xarray-0.20.2        | 628 KB    |            |   0%
# xarray-0.20.2        | 628 KB    | #####8     |  59%
# xarray-0.20.2        | 628 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed

# %%
dataset = pd.read_csv("eda_train.csv")
